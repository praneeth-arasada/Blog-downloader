# %%
import csv
import time
from urllib.parse import urlparse, urljoin
import requests

file_location = 'D:\Downloads\input-pages-blog-majestic-com.csv'
output_dir = r"C:\Users\alpra\Documents\blog-down"
index_csv_location = '{}/index-file.csv'.format(output_dir)

# Open the CSV file in read mode
with open(file_location, encoding='utf-8-sig') as csv_file:
    csv_reader = csv.DictReader(csv_file)

    # A set of resources to fetch later
    prospects = set()
    for row in csv_reader:
        url = urlparse(row['URL'])

        if not url.path.endswith(('/feed/', '.png', '.jpg', '.gif')):
            prospects.add(urljoin(row["URL"], url.path))

    print('There are {} prospective pages'.format(len(prospects)))

# Open index file to write output
with open(index_csv_location, mode='w', newline='', encoding='utf-8-sig') as index_csv:
    fieldnames = ['id', 'url', 'filename', 'status', 'location']
    writer = csv.DictWriter(index_csv, fieldnames=fieldnames)
    writer.writeheader()

    page_id = 0

    for url in prospects:
        print('Processing {}'.format(url))

        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            location = ''
            if response.is_redirect:
                location = response.headers.get('Location')
            elif response.status_code == 200:
                response = requests.get(url)

                cache_filename = '{}/page-{}.html'.format(output_dir, page_id)
                with open(cache_filename, mode='w', encoding='utf-8') as cache:
                    cache.write(response.text)

            writer.writerow({
                'id': page_id,
                'url': url,
                'filename': cache_filename,
                'status': response.status_code,
                'location': location
            })
        else:
            print('Ignoring non-HTML content type "{}"'.format(content_type))

        # Pause the execution of the script to prevent an aggressive spam of requests
        time.sleep(1)
# Out:
# There are 32 prospective pages
# Processing https://blog.majestic.com/general/track-competitors-subdomain-root-domain-home-page/
# Processing https://blog.majestic.com/training/a-guide-to-the-majestic-site-explorer/embed/
# Processing https://blog.majestic.com/general/majestic-seo-fo-facebook/
# Processing https://blog.majestic.com/pl/sieci-spolecznosciowe/wywiad-bartosz-szlachetka-moja-kariera-w-seo/
# Processing https://blog.majestic.com/training/how-to-optimise-your-site-for-yandex-part-2/
# Processing https://blog.majestic.com/majestic-seo-partners/
# Processing https://blog.majestic.com/development/compare-backlinks/
# Processing https://blog.majestic.com/pl/uncategorized-pl/wskazniki-trust-i-citation-flow/
# Processing https://blog.majestic.com/general/3d-printing-in-space/
# Processing https://blog.majestic.com/general/site-explorer-tutorial-2/
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/randomurlgenerator.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/pl/general/po-polsku/analiza-domeny-majestic-search-explorer-cz1/
# Processing https://blog.majestic.com/company/understanding-googles-algorithm-how-pagerank-works/
# Processing https://blog.majestic.com/company/new-domains-now-available-in-site-explorer-preview/
# Processing https://blog.majestic.com/pl/general/po-polsku/mamy-nadzieje-ze-aktualizacje-wyszukiwarki-site-explorer-nie-uszly-twojej-uwadze
# Processing http://blog.majestic.com/
# Processing https://blog.majestic.com/development/flow-metrics/
# Processing https://blog.majestic.com/how-to-videos/
# Processing https://blog.majestic.com/pl/objasnienia/linki-nofollow-czym-sa-i-jakie-maja-znaczenie-w-pozycjonowaniu/
# Processing https://blog.majestic.com/general/historic-index-update-8/
# Processing https://blog.majestic.com/wp-content/uploads/2019/10/109.Link_Context_Manual_it.pdf
# Ignoring non-HTML content type "application/pdf"
# Processing https://blog.majestic.com/case-studies/million/
# Processing https://blog.majestic.com/wp-content/uploads/2016/03/MajesticInSpace-MediaRelease.pdf
# Ignoring non-HTML content type "application/pdf"
# Processing https://blog.majestic.com/commentary/inside-trust-flow/
# Processing https://blog.majestic.com/
# Processing https://blog.majestic.com/company/twitter/
# Processing https://blog.majestic.com/general/using-majestic-citation-flow-trust-flow-check-quality-link-prospects/
# Processing http://blog.majestic.com/ambassadors/
# Processing https://blog.majestic.com/pl/sieci-spolecznosciowe/5-mitow-seo-pawel-gontarek/
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/Comparison_Template.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/DomainExtractionFromURL.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/company/win-an-ipad/

# %%
import requests
from bs4 import BeautifulSoup
from os import path
import time
import csv
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen



output_dir = r"C:\Users\alpra\Documents\blog-down"
index_csv_location = '{}/index-file.csv'.format(output_dir)

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
with open(index_csv_location, mode='w', newline='', encoding='utf-8-sig') as index_csv:
    fieldnames = ['id', 'url', 'filename', 'status', 'location']
    writer = csv.DictWriter(index_csv, fieldnames=fieldnames)
    writer.writeheader()
    page_id = 0
    for link in soup.find_all('a', class_="story-link"):
        url = link.get('href')
        html = urlopen(url)
        response = urllib.request.urlopen(url)
        webContent = response.read()
        print('Processing {}'.format(url))
        

        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            location = ''
            if response.is_redirect:
                location = response.headers.get('Location')
            elif response.status_code == 200:
                response = requests.get(url)

                cache_filename = '{}/page-{}.html'.format(output_dir, page_id)
                with open(cache_filename, mode='w', encoding='utf-8') as cache:
                    cache.write(response.text)

            writer.writerow({
                'id': page_id,
                'url': url,
                'filename': cache_filename,
                'status': response.status_code,
                'location': location
            })
        else:
            print('Ignoring non-HTML content type "{}"'.format(content_type))
# Out:
# title: The Hacker News - Cybersecurity News and Analysis
# links:
# Processing https://thehackernews.com/2021/06/hackers-breached-colonial-pipeline.html
# Processing https://thehackernews.com/2021/06/latvian-woman-charged-for-her-role-in.html
# Processing https://thehackernews.com/2021/06/github-updates-policy-to-remove-exploit.html
# Processing https://thehackernews.com/2021/06/break-into-ethical-hacking-with-18.html
# Processing https://thehackernews.com/2021/06/tiktok-quietly-updated-its-privacy.html
# Processing https://thehackernews.com/2021/06/alert-critical-rce-bug-in-vmware.html
# Processing https://thehackernews.com/2021/06/google-to-let-android-users-opt-out-to.html
# Processing https://thehackernews.com/2021/06/10-critical-flaws-found-in-codesys.html

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen



output_dir = r"C:\Users\alpra\Documents\blog-down"

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
page_id = 0
for link in soup.find_all('entry'):
        url = link.get('href')
        html = urlopen(url)
        response = urllib.request.urlopen(url)
        webContent = response.read()
        print('Processing {}'.format(url))
        

        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            response = requests.get(url)
            cache_filename = '{}/page-{}.html'.format(output_dir, page_id)
            with open(cache_filename, mode='w', encoding='utf-8') as cache:
                cache.write(response.text)
# Out:
# title: Schneier on Security
# links:
# None
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-5-8b187b799c62> in <module>
#      18         url = link.get('href')
#      19         print(url)
# ---> 20         response = requests.get(url)
#      21         webContent = response.read()
#      22         print('Processing {}'.format(url))
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     388             error = error.format(to_native_string(url, 'utf8'))
#     389
# --> 390             raise MissingSchema(error)
#     391
#     392         if not host:
#
# MissingSchema: Invalid URL 'None': No schema supplied. Perhaps you meant http://None?

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen



output_dir = r"C:\Users\alpra\Documents\blog-down\The Hacker News"

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')   
page_id = 0
for link in soup.find_all('a', class_="story-link"):
    for h2 in soup.find('h2',class_='home-title'):
        url = link.get('href')
        title = link.div.h2.get_text()
        html = urlopen(url)
        response = urllib.request.urlopen(url)
        webContent = response.read()
        print('Title:  {}'.format(title))
        print('Processing {}'.format(url))
        
        if not url.endswith(('/feed/', '.png', '.jpg', '.gif')):
            page_id += 1
            cache_filename = ''
            response = requests.get(url)
            cache_filename = '{}/{} -{}.html'.format(output_dir, title, page_id)
            with open(cache_filename, mode='w', encoding='utf-8') as cache:
                cache.write(response.text)
        time.sleep(1)
# Out:
# title: The Hacker News - Cybersecurity News and Analysis
# links:
# Title:  New UAF Vulnerability Affecting Microsoft Office to be Patched Today
# Processing https://thehackernews.com/2021/06/new-uaf-vulnerability-affecting.html
# Title:  Top 10 Privacy and Security Features Apple Announced at WWDC 2021
# Processing https://thehackernews.com/2021/06/top-10-privacy-and-security-features.html
# Title:  U.S. Recovers $2.3 Million Ransom Paid to Colonial Pipeline Hackers
# Processing https://thehackernews.com/2021/06/us-recovers-23-million-ransom-paid-to.html
# Title:  Shifting the focus from reactive to proactive, with human-led secure coding
# Processing https://thehackernews.com/2021/06/shifting-focus-from-reactive-to.html
# Title:  Researchers Discover First Known Malware Targeting Windows Containers
# Processing https://thehackernews.com/2021/06/researchers-discover-first-known.html
# Title:  Hackers Breached Colonial Pipeline Using Compromised VPN Password
# Processing https://thehackernews.com/2021/06/hackers-breached-colonial-pipeline.html
# Title:  Latvian Woman Charged for Her Role in Creating Trickbot Banking Malware
# Processing https://thehackernews.com/2021/06/latvian-woman-charged-for-her-role-in.html
# Title:  GitHub Updates Policy to Remove Exploit Code When Used in Active Attacks
# Processing https://thehackernews.com/2021/06/github-updates-policy-to-remove-exploit.html

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen

output_dir = r"C:\Users\alpra\Documents\blog-down\Zero Day"
                
response = requests.get('https://threatpost.com/feed/')

soup = BeautifulSoup(response.text, 'html.parser')

print('Title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a', class_='thumb'):
            url = 'https://www.zdnet.com/blog/security/{}'.format(link.get('href'))
            title = link.get('title')
            html = urlopen(url)
            response = urllib.request.urlopen(url)
            webContent = response.read()
            print('Title:  {}'.format(title))
            print('Processing {}'.format(url))
            

            if not url.endswith(('/feed/', '.png', '.jpg', '.gif')):
                page_id += 1
                cache_filename = ''
                response = requests.get(url)
                cache_filename = '{}/{}_page-{}.html'.format(output_dir, title, page_id)
                with open(cache_filename, mode='w', encoding='utf-8') as cache:
                    cache.write(response.text)
                    
            time.sleep(1)
# Out:
# Title: Threatpost
# links:

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen

output_dir = r"C:\Users\alpra\Documents\blog-down\ThreatPost"
                
response = requests.get('https://threatpost.com/feed/')

soup = BeautifulSoup(response.content, features='xml')

for item in soup.find_all('channel'):
            title = item.get_text('title')
            title = title.replace('?', ' ')
            title = title.replace(':', ' ')
            date = item.get_text('pubDate')
            link = item.get('link')

            print(title)
            print(date)
            print(link)
            print()

            # Fetch header first to get check content type
            response = requests.head(link)
            # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
            content_type = response.headers.get('Content-Type').split(';')[0]

            if content_type == 'text/html':
                response = urllib.request.urlopen(link)
                webContent = response.read()
                f = open('{}/{}.html'.format(output_dir, title), 'wb')
                f.write(webContent)
                f.close
                    
            time.sleep(1)
# Out:
# titleThreatposttitle
# title
# titlehttps //threatpost.comtitle
# titleThe First Stop For Security Newstitle
# titleMon, 07 Jun 2021 21 35 25 +0000title
# titleen-UStitle
# title
# 	hourly	title
# title
# 	1	title
# titlehttps //wordpress.org/ v=5.7.2title
# title title
# titleFBI Claws Back Millions of DarkSide’s Ransom Profitstitle
# titlehttps //threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/title
# titlehttps //threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/#respondtitle
# titleLisa Vaastitle
# titleMon, 07 Jun 2021 20 54 07 +0000title
# titleGovernmenttitle
# titleHackstitle
# titleMalwaretitle
# titleWeb Securitytitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166705title
# titleThe tables have been turned, the FBI &#38; DOJ said after announcing the use of blockchain technology to track down the contents of DarkSide's cryptocurrency wallet.title
# titlehttps //threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleBad Apple  App Store Rife with Fraud, Fleecewaretitle
# titlehttps //threatpost.com/apple-app-store-fraud-fleeceware/166703/title
# titlehttps //threatpost.com/apple-app-store-fraud-fleeceware/166703/#respondtitle
# titleBecky Brackentitle
# titleMon, 07 Jun 2021 19 37 51 +0000title
# titleMalwaretitle
# titleMobile Securitytitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166703title
# titleMalicious apps make up 2 percent of top grossing apps in Apple App Store.title
# titlehttps //threatpost.com/apple-app-store-fraud-fleeceware/166703/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleNovel ‘Victory’ Backdoor Spotted in Chinese APT Campaigntitle
# titlehttps //threatpost.com/victory-backdoor-apt-campaign/166700/title
# titlehttps //threatpost.com/victory-backdoor-apt-campaign/166700/#respondtitle
# titleTara Sealstitle
# titleMon, 07 Jun 2021 18 49 44 +0000title
# titleMalwaretitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166700title
# titleResearchers said the malware has been under development for at least three years.title
# titlehttps //threatpost.com/victory-backdoor-apt-campaign/166700/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleWindows Container Malware Targets Kubernetes Clusterstitle
# titlehttps //threatpost.com/windows-containers-malware-targets-kubernetes/166692/title
# titlehttps //threatpost.com/windows-containers-malware-targets-kubernetes/166692/#respondtitle
# titleLisa Vaastitle
# titleMon, 07 Jun 2021 17 18 48 +0000title
# titleCloud Securitytitle
# titleVulnerabilitiestitle
# titleWeb Securitytitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166692title
# title“Siloscape”, the first malware to target Windows containers, breaks out of Kubernetes clusters to plant backdoors and raid nodes for credentials.
# title
# titlehttps //threatpost.com/windows-containers-malware-targets-kubernetes/166692/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleCyberattack Suspected in Cox TV and Radio Outagestitle
# titlehttps //threatpost.com/cyberattack-cox-outage-tv-radio/166680/title
# titlehttps //threatpost.com/cyberattack-cox-outage-tv-radio/166680/#commentstitle
# titleBecky Brackentitle
# titleFri, 04 Jun 2021 20 21 48 +0000title
# titleMalwaretitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166680title
# titleCox Media Group tv, radio station streams affected by a reported ransomware attack.title
# titlehttps //threatpost.com/cyberattack-cox-outage-tv-radio/166680/feed/title
# title2title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleSupreme Court Limits Scope of Controversial Hacking Lawtitle
# titlehttps //threatpost.com/court-limits-scope-hacking-law/166672/title
# titlehttps //threatpost.com/court-limits-scope-hacking-law/166672/#respondtitle
# titleElizabeth Montalbanotitle
# titleFri, 04 Jun 2021 14 15 16 +0000title
# titleGovernmenttitle
# titleHackstitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166672title
# titleJudges rule that Georgia police officer did not violate CFAA when he accessed law-enforcement data in exchange for bribe money, a ruling that takes heat off ethical hackers.title
# titlehttps //threatpost.com/court-limits-scope-hacking-law/166672/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleREvil Ransomware Gang Spill Details on US Attackstitle
# titlehttps //threatpost.com/revil-spill-details-us-attacks/166669/title
# titlehttps //threatpost.com/revil-spill-details-us-attacks/166669/#respondtitle
# titleTom Springtitle
# titleFri, 04 Jun 2021 13 19 02 +0000title
# titleGovernmenttitle
# titleHackstitle
# titleMalwaretitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166669title
# titleThe REvil ransomware gang is interviewed on the Telegram channel called Russian OSINT. title
# titlehttps //threatpost.com/revil-spill-details-us-attacks/166669/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# title‘Battle for the Galaxy’ Mobile Game Leaks 6M Gamer Profilestitle
# titlehttps //threatpost.com/battle-for-the-galaxy-leaks/166659/title
# titlehttps //threatpost.com/battle-for-the-galaxy-leaks/166659/#respondtitle
# titleBecky Brackentitle
# titleThu, 03 Jun 2021 22 06 39 +0000title
# titleBreachtitle
# titleVulnerabilitiestitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166659title
# titleUnprotected server exposes AMT Games user data containing user emails and purchase information.title
# titlehttps //threatpost.com/battle-for-the-galaxy-leaks/166659/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleGoogle PPC Ads Used to Deliver Infostealerstitle
# titlehttps //threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/title
# titlehttps //threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/#respondtitle
# titleLisa Vaastitle
# titleThu, 03 Jun 2021 18 20 15 +0000title
# titleMalwaretitle
# titleWeb Securitytitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166644title
# titleThe crooks pay top dollar for Google search results for the popular AnyDesk, Dropbox &#38; Telegram apps that lead to a malicious, infostealer-packed website.title
# titlehttps //threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/feed/title
# title0title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
# title
# titleExchange Servers Targeted by ‘Epsilon Red’ Malwaretitle
# titlehttps //threatpost.com/exchange-servers-epsilon-red-ransomware/166640/title
# titlehttps //threatpost.com/exchange-servers-epsilon-red-ransomware/166640/#commentstitle
# titleElizabeth Montalbanotitle
# titleThu, 03 Jun 2021 12 47 04 +0000title
# titleCryptographytitle
# titleMalwaretitle
# titleVulnerabilitiestitle
# titlehttps //kasperskycontenthub.com/threatpost-global/ p=166640title
# titleREvil threat actors may be behind a set of PowerShell scripts developed for encryption and weaponized to exploit vulnerabilities in corporate networks, the ransom note suggests.title
# titlehttps //threatpost.com/exchange-servers-epsilon-red-ransomware/166640/feed/title
# title3title
# titlefulltitle
# titlelargetitle
# titlemediumtitle
# titlethumbnailtitle
# title
#
#
# pubDateThreatpostpubDate
# pubDate
# pubDatehttps://threatpost.compubDate
# pubDateThe First Stop For Security NewspubDate
# pubDateMon, 07 Jun 2021 21:35:25 +0000pubDate
# pubDateen-USpubDate
# pubDate
# 	hourly	pubDate
# pubDate
# 	1	pubDate
# pubDatehttps://wordpress.org/?v=5.7.2pubDate
# pubDate pubDate
# pubDateFBI Claws Back Millions of DarkSide’s Ransom ProfitspubDate
# pubDatehttps://threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/pubDate
# pubDatehttps://threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/#respondpubDate
# pubDateLisa VaaspubDate
# pubDateMon, 07 Jun 2021 20:54:07 +0000pubDate
# pubDateGovernmentpubDate
# pubDateHackspubDate
# pubDateMalwarepubDate
# pubDateWeb SecuritypubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166705pubDate
# pubDateThe tables have been turned, the FBI &#38; DOJ said after announcing the use of blockchain technology to track down the contents of DarkSide's cryptocurrency wallet.pubDate
# pubDatehttps://threatpost.com/fbi-claws-back-millions-darksides-ransom/166705/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateBad Apple: App Store Rife with Fraud, FleecewarepubDate
# pubDatehttps://threatpost.com/apple-app-store-fraud-fleeceware/166703/pubDate
# pubDatehttps://threatpost.com/apple-app-store-fraud-fleeceware/166703/#respondpubDate
# pubDateBecky BrackenpubDate
# pubDateMon, 07 Jun 2021 19:37:51 +0000pubDate
# pubDateMalwarepubDate
# pubDateMobile SecuritypubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166703pubDate
# pubDateMalicious apps make up 2 percent of top grossing apps in Apple App Store.pubDate
# pubDatehttps://threatpost.com/apple-app-store-fraud-fleeceware/166703/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateNovel ‘Victory’ Backdoor Spotted in Chinese APT CampaignpubDate
# pubDatehttps://threatpost.com/victory-backdoor-apt-campaign/166700/pubDate
# pubDatehttps://threatpost.com/victory-backdoor-apt-campaign/166700/#respondpubDate
# pubDateTara SealspubDate
# pubDateMon, 07 Jun 2021 18:49:44 +0000pubDate
# pubDateMalwarepubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166700pubDate
# pubDateResearchers said the malware has been under development for at least three years.pubDate
# pubDatehttps://threatpost.com/victory-backdoor-apt-campaign/166700/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateWindows Container Malware Targets Kubernetes ClusterspubDate
# pubDatehttps://threatpost.com/windows-containers-malware-targets-kubernetes/166692/pubDate
# pubDatehttps://threatpost.com/windows-containers-malware-targets-kubernetes/166692/#respondpubDate
# pubDateLisa VaaspubDate
# pubDateMon, 07 Jun 2021 17:18:48 +0000pubDate
# pubDateCloud SecuritypubDate
# pubDateVulnerabilitiespubDate
# pubDateWeb SecuritypubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166692pubDate
# pubDate“Siloscape”, the first malware to target Windows containers, breaks out of Kubernetes clusters to plant backdoors and raid nodes for credentials.
# pubDate
# pubDatehttps://threatpost.com/windows-containers-malware-targets-kubernetes/166692/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateCyberattack Suspected in Cox TV and Radio OutagespubDate
# pubDatehttps://threatpost.com/cyberattack-cox-outage-tv-radio/166680/pubDate
# pubDatehttps://threatpost.com/cyberattack-cox-outage-tv-radio/166680/#commentspubDate
# pubDateBecky BrackenpubDate
# pubDateFri, 04 Jun 2021 20:21:48 +0000pubDate
# pubDateMalwarepubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166680pubDate
# pubDateCox Media Group tv, radio station streams affected by a reported ransomware attack.pubDate
# pubDatehttps://threatpost.com/cyberattack-cox-outage-tv-radio/166680/feed/pubDate
# pubDate2pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateSupreme Court Limits Scope of Controversial Hacking LawpubDate
# pubDatehttps://threatpost.com/court-limits-scope-hacking-law/166672/pubDate
# pubDatehttps://threatpost.com/court-limits-scope-hacking-law/166672/#respondpubDate
# pubDateElizabeth MontalbanopubDate
# pubDateFri, 04 Jun 2021 14:15:16 +0000pubDate
# pubDateGovernmentpubDate
# pubDateHackspubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166672pubDate
# pubDateJudges rule that Georgia police officer did not violate CFAA when he accessed law-enforcement data in exchange for bribe money, a ruling that takes heat off ethical hackers.pubDate
# pubDatehttps://threatpost.com/court-limits-scope-hacking-law/166672/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateREvil Ransomware Gang Spill Details on US AttackspubDate
# pubDatehttps://threatpost.com/revil-spill-details-us-attacks/166669/pubDate
# pubDatehttps://threatpost.com/revil-spill-details-us-attacks/166669/#respondpubDate
# pubDateTom SpringpubDate
# pubDateFri, 04 Jun 2021 13:19:02 +0000pubDate
# pubDateGovernmentpubDate
# pubDateHackspubDate
# pubDateMalwarepubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166669pubDate
# pubDateThe REvil ransomware gang is interviewed on the Telegram channel called Russian OSINT. pubDate
# pubDatehttps://threatpost.com/revil-spill-details-us-attacks/166669/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDate‘Battle for the Galaxy’ Mobile Game Leaks 6M Gamer ProfilespubDate
# pubDatehttps://threatpost.com/battle-for-the-galaxy-leaks/166659/pubDate
# pubDatehttps://threatpost.com/battle-for-the-galaxy-leaks/166659/#respondpubDate
# pubDateBecky BrackenpubDate
# pubDateThu, 03 Jun 2021 22:06:39 +0000pubDate
# pubDateBreachpubDate
# pubDateVulnerabilitiespubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166659pubDate
# pubDateUnprotected server exposes AMT Games user data containing user emails and purchase information.pubDate
# pubDatehttps://threatpost.com/battle-for-the-galaxy-leaks/166659/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateGoogle PPC Ads Used to Deliver InfostealerspubDate
# pubDatehttps://threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/pubDate
# pubDatehttps://threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/#respondpubDate
# pubDateLisa VaaspubDate
# pubDateThu, 03 Jun 2021 18:20:15 +0000pubDate
# pubDateMalwarepubDate
# pubDateWeb SecuritypubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166644pubDate
# pubDateThe crooks pay top dollar for Google search results for the popular AnyDesk, Dropbox &#38; Telegram apps that lead to a malicious, infostealer-packed website.pubDate
# pubDatehttps://threatpost.com/google-ppc-ads-used-to-deliver-infostealers/166644/feed/pubDate
# pubDate0pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
# pubDate
# pubDateExchange Servers Targeted by ‘Epsilon Red’ MalwarepubDate
# pubDatehttps://threatpost.com/exchange-servers-epsilon-red-ransomware/166640/pubDate
# pubDatehttps://threatpost.com/exchange-servers-epsilon-red-ransomware/166640/#commentspubDate
# pubDateElizabeth MontalbanopubDate
# pubDateThu, 03 Jun 2021 12:47:04 +0000pubDate
# pubDateCryptographypubDate
# pubDateMalwarepubDate
# pubDateVulnerabilitiespubDate
# pubDatehttps://kasperskycontenthub.com/threatpost-global/?p=166640pubDate
# pubDateREvil threat actors may be behind a set of PowerShell scripts developed for encryption and weaponized to exploit vulnerabilities in corporate networks, the ransom note suggests.pubDate
# pubDatehttps://threatpost.com/exchange-servers-epsilon-red-ransomware/166640/feed/pubDate
# pubDate3pubDate
# pubDatefullpubDate
# pubDatelargepubDate
# pubDatemediumpubDate
# pubDatethumbnailpubDate
# pubDate
#
# None
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-20-4b025924a464> in <module>
#      25
#      26             # Fetch header first to get check content type
# ---> 27             response = requests.head(link)
#      28             # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
#      29             content_type = response.headers.get('Content-Type').split(';')[0]
#
# ~\anaconda3\lib\site-packages\requests\api.py in head(url, **kwargs)
#     102
#     103     kwargs.setdefault('allow_redirects', False)
# --> 104     return request('head', url, **kwargs)
#     105
#     106
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     388             error = error.format(to_native_string(url, 'utf8'))
#     389
# --> 390             raise MissingSchema(error)
#     391
#     392         if not host:
#
# MissingSchema: Invalid URL 'None': No schema supplied. Perhaps you meant http://None?
