# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = 'https://www.zdnet.com/blog/security/'
html = urlopen(url)
response = urllib.request.urlopen(url)
webContent = response.read()
f = open('obo-t17800628-33.html', 'wb')
f.write(webContent)
f.close
# Out:
# <function BufferedWriter.close>

# %%
import requests

response = requests.get('https://informationsecuritybuzz.com/')

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="profile" href="http://gmpg.org/xfn/11" />
# 		<link rel="alternate" type="application/rss+xml" title="Information Security Buzz RSS Feed" href="https://informationsecuritybuzz.com/feed/" />
# 	<link rel="alternate" type="application/atom+xml" title="Information Security Buzz Atom Feed" href="https://informationsecuritybuzz.com/feed/atom/" />
# 	<link rel="pingback" href="https://informationsecuritybuzz.com/xmlrpc.php" />
# 	<!--[if lt IE 9]>
# 	<script src="https://informationsecuritybuzz.com/wp-content/themes/soledad/js/html5.js"></script>
# 	<![endif]-->
# 	<link rel='preconnect' href='https://fonts.googleapis.com' />
# <link rel='preconnect' href='https://fonts.gstatic.com' />
# <meta http-equiv='x-dns-prefetch-control' content='on'>
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//fonts.gstatic.com' />
# <link rel='dns-prefetch' href='//s.gravatar.com' />
# <link rel='dns-prefetch' href='//www.google-analytics.com' />
# <link rel='preload' as='image' href='https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png' type='image/png'>
# <link rel='preload' as='font' href='https://informationsecuritybuzz.com/wp-content/themes/soledad/fonts/fontawesome-webfont.woff2?v=4.7.0' type='font/woff2' crossorigin='anonymous' />
# <link rel='preload' as='font' href='https://informationsecuritybuzz.com/wp-content/themes/soledad/fonts/weathericons.woff2' type='font/woff2' crossorigin='anonymous' />
# <meta name='robots' content='max-image-preview:large' />
#
# 	<!-- This site is optimized with the Yoast SEO Premium plugin v15.7 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>Information Security News | Security Experts Comments On Latest News</title>
# 	<meta name="description" content="Security experts including CISO and CEO of Fortune 100 companies comments on the latest Information Security News. Excellent source of Learning." />
# 	<meta name="robots" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
# 	<link rel="canonical" href="https://informationsecuritybuzz.com/" />
# 	<meta property="og:locale" content="en_US" />
# 	<meta property="og:type" content="website" />
# 	<meta property="og:title" content="Information Security News | Security Experts Comments On Latest News" />
# 	<meta property="og:description" content="Security experts including CISO and CEO of Fortune 100 companies comments on the latest Information Security News. Excellent source of Learning." />
# 	<meta property="og:url" content="https://informationsecuritybuzz.com/" />
# 	<meta property="og:site_name" content="Information Security Buzz" />
# 	<meta property="article:publisher" content="https://www.facebook.com/InfoSecBuzz" />
# 	<meta property="article:modified_time" content="2021-06-07T05:21:55+00:00" />
# 	<meta property="og:image" content="https://informationsecuritybuzz.com/wp-content/uploads/socio-black-1.png" />
# 	<meta property="og:image:width" content="1269" />
# 	<meta property="og:image:height" content="622" />
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:site" content="@Info_Sec_Buzz" />
# 	<meta name="twitter:label1" content="Est. reading time">
# 	<meta name="twitter:data1" content="3 minutes">
# 	<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.informationsecuritybuzz.com/#organization","name":"Information Security Buzz","url":"https://www.informationsecuritybuzz.com/","sameAs":["https://www.facebook.com/InfoSecBuzz","https://www.linkedin.com/company/information-security-buzz/","https://www.youtube.com/channel/UCtfofFm4HDfeNxJnyzq1K6g","https://www.pinterest.com/infosecbuzz/","https://twitter.com/Info_Sec_Buzz"],"logo":{"@type":"ImageObject","@id":"https://www.informationsecuritybuzz.com/#logo","inLanguage":"en-US","url":"https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-logo-9Asset-7-1.png","width":1478,"height":1194,"caption":"Information Security Buzz"},"image":{"@id":"https://www.informationsecuritybuzz.com/#logo"}},{"@type":"WebSite","@id":"https://www.informationsecuritybuzz.com/#website","url":"https://www.informationsecuritybuzz.com/","name":"Information Security Buzz","description":"Experts Comments on Information Security News","publisher":{"@id":"https://www.informationsecuritybuzz.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":"https://www.informationsecuritybuzz.com/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://informationsecuritybuzz.com/#webpage","url":"https://informationsecuritybuzz.com/","name":"Information Security News | Security Experts Comments On Latest News","isPartOf":{"@id":"https://www.informationsecuritybuzz.com/#website"},"about":{"@id":"https://www.informationsecuritybuzz.com/#organization"},"datePublished":"2021-06-02T13:15:13+00:00","dateModified":"2021-06-07T05:21:55+00:00","description":"Security experts including CISO and CEO of Fortune 100 companies comments on the latest Information Security News. Excellent source of Learning.","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://informationsecuritybuzz.com/"]}]},{"@type":"BreadcrumbList","@id":"https://informationsecuritybuzz.com/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://informationsecuritybuzz.com/","url":"https://informationsecuritybuzz.com/","name":"Home"}}]}]}</script>
# 	<meta name="google-site-verification" content="IMuowQM1DcBRaPgbJM_oD8zvqbzU-8-JPm6InNEPXPE" />
# 	<!-- / Yoast SEO Premium plugin. -->
#
#
# <link rel='dns-prefetch' href='//js.hs-scripts.com' />
# <link rel='dns-prefetch' href='//www.googletagmanager.com' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//use.fontawesome.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel='dns-prefetch' href='//smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com' />
# <link rel='preconnect' href='https://fonts.gstatic.com' />
# <link rel='preconnect' href='https://fonts.googleapis.com' />
# <link rel="alternate" type="application/rss+xml" title="Information Security Buzz &raquo; Feed" href="https://informationsecuritybuzz.com/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Information Security Buzz &raquo; Comments Feed" href="https://informationsecuritybuzz.com/comments/feed/" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/informationsecuritybuzz.com\/wp-includes\/js\/wp-emoji-release.min.js"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<!-- informationsecuritybuzz.com is managing ads with Advanced Ads --><script>
# 			advanced_ads_ready=function(){var e,t=[],n="object"==typeof document&&document,d=n&&n.documentElement.doScroll,o="DOMContentLoaded",a=n&&(d?/^loaded|^c/:/^loaded|^i|^c/).test(n.readyState);return!a&&n&&(e=function(){for(n.removeEventListener(o,e),window.removeEventListener("load",e),a=1;e=t.shift();)e()},n.addEventListener(o,e),window.addEventListener("load",e)),function(e){a?setTimeout(e,0):t.push(e)}}();		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel='stylesheet' id='wphb-1-css'  href='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/665592fcb02fb86706a96585fb77b4ed.css' type='text/css' media='all' />
# <link rel='stylesheet' id='wphb-2-css'  href='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/267a1d3a0c2ff1ce6ca9c510d9fce295.css' type='text/css' media='all' />
# <link rel='stylesheet' id='tve_style_family_tve_flt-css'  href='https://informationsecuritybuzz.com/wp-content/plugins/thrive-visual-editor/editor/css/thrive_flat.css' type='text/css' media='all' />
# <link rel='stylesheet' id='penci-fonts-css'  href='//fonts.googleapis.com/css?family=Raleway%3A300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C700%2C700italic%2C800%2C800italic%7CPT+Serif%3A300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C700%2C700italic%2C800%2C800italic%7CPlayfair+Display+SC%3A300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C700%2C700italic%2C800%2C800italic%7CMontserrat%3A300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C700%2C700italic%2C800%2C800italic%26subset%3Dlatin%2Ccyrillic%2Ccyrillic-ext%2Cgreek%2Cgreek-ext%2Clatin-ext&#038;display=swap&#038;ver=1.0' type='text/css' media='all' />
# <link rel='stylesheet' id='wphb-3-css'  href='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/1783c8c081d7305cb52bfc6e3f6090f9.css' type='text/css' media='all' />
# <style id='wphb-3-inline-css' type='text/css'>
#
# 			@font-face {
# 				font-family: 'FontAwesome';
# 				src: url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.eot'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.eot?#iefix') format('embedded-opentype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.woff2') format('woff2'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.woff') format('woff'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.ttf') format('truetype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-brands-400.svg#fontawesome') format('svg');
# 			}
#
# 			@font-face {
# 				font-family: 'FontAwesome';
# 				src: url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.eot'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.eot?#iefix') format('embedded-opentype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.woff2') format('woff2'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.woff') format('woff'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.ttf') format('truetype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-solid-900.svg#fontawesome') format('svg');
# 			}
#
# 			@font-face {
# 				font-family: 'FontAwesome';
# 				src: url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.eot'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.eot?#iefix') format('embedded-opentype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.woff2') format('woff2'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.woff') format('woff'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.ttf') format('truetype'),
# 				url('https://use.fontawesome.com/releases/v5.15.3/webfonts/fa-regular-400.svg#fontawesome') format('svg');
# 				unicode-range: U+F004-F005,U+F007,U+F017,U+F022,U+F024,U+F02E,U+F03E,U+F044,U+F057-F059,U+F06E,U+F070,U+F075,U+F07B-F07C,U+F080,U+F086,U+F089,U+F094,U+F09D,U+F0A0,U+F0A4-F0A7,U+F0C5,U+F0C7-F0C8,U+F0E0,U+F0EB,U+F0F3,U+F0F8,U+F0FE,U+F111,U+F118-F11A,U+F11C,U+F133,U+F144,U+F146,U+F14A,U+F14D-F14E,U+F150-F152,U+F15B-F15C,U+F164-F165,U+F185-F186,U+F191-F192,U+F1AD,U+F1C1-F1C9,U+F1CD,U+F1D8,U+F1E3,U+F1EA,U+F1F6,U+F1F9,U+F20A,U+F247-F249,U+F24D,U+F254-F25B,U+F25D,U+F267,U+F271-F274,U+F279,U+F28B,U+F28D,U+F2B5-F2B6,U+F2B9,U+F2BB,U+F2BD,U+F2C1-F2C2,U+F2D0,U+F2D2,U+F2DC,U+F2ED,U+F328,U+F358-F35B,U+F3A5,U+F3D1,U+F410,U+F4AD;
# 			}
#
# </style>
# <script type='text/javascript' src='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/5d613ff3c531b24e872bd48fc0b31d8a.js' id='wphb-4-js'></script>
# <script type='text/javascript' src='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/90c03b8984c8f0ad24433d3fe85ee951.js' id='wphb-5-js'></script>
# <script type='text/javascript' src='https://www.googletagmanager.com/gtag/js?id=UA-41913859-1' id='google_gtagjs-js' async></script>
# <script type='text/javascript' id='google_gtagjs-js-after'>
# window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
# gtag('set', 'linker', {"domains":["informationsecuritybuzz.com"]} );
# gtag("js", new Date());
# gtag("set", "developer_id.dZTNiMT", true);
# gtag("config", "UA-41913859-1", {"anonymize_ip":true});
# </script>
# <link rel="https://api.w.org/" href="https://informationsecuritybuzz.com/wp-json/" /><link rel="alternate" type="application/json" href="https://informationsecuritybuzz.com/wp-json/wp/v2/pages/702390" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://informationsecuritybuzz.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://informationsecuritybuzz.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 5.7.2" />
# <link rel='shortlink' href='https://informationsecuritybuzz.com/' />
# <link rel="alternate" type="application/json+oembed" href="https://informationsecuritybuzz.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Finformationsecuritybuzz.com%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://informationsecuritybuzz.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Finformationsecuritybuzz.com%2F&#038;format=xml" />
# <script type="text/javascript">
#            var ajax_url_author_box_plugin = "https://informationsecuritybuzz.com/wp-admin/admin-ajax.php";
#            var base_url_of_the_site = "https://informationsecuritybuzz.com";
#          window.PAGE_TYPE = "" ;
#          </script><script type="text/javascript">
#            var ajax_url_cyber_security_directory_plugin = "https://informationsecuritybuzz.com/wp-admin/admin-ajax.php";
#            var base_url_of_the_site = "https://informationsecuritybuzz.com";
#          window.PAGE_TYPE = "" ;
#          </script>
# 		<!-- GA Google Analytics @ https://m0n.co/ga -->
# 		<script async src="https://www.googletagmanager.com/gtag/js?id=UA-41913859-1"></script>
# 		<script>
# 			window.dataLayer = window.dataLayer || [];
# 			function gtag(){dataLayer.push(arguments);}
# 			gtag('js', new Date());
# 			gtag('config', 'UA-41913859-1');
# 		</script>
#
# 	<meta name="generator" content="Site Kit by Google 1.33.0" />			<!-- DO NOT COPY THIS SNIPPET! Start of Page Analytics Tracking for HubSpot WordPress plugin v8.0.227-->
# 			<script type="text/javascript">
# 				var _hsq = _hsq || [];
# 				_hsq.push(["setContentType", "standard-page"]);
# 			</script>
# 			<!-- DO NOT COPY THIS SNIPPET! End of Page Analytics Tracking for HubSpot WordPress plugin -->
# 						<script>
# 				(function() {
# 					var hbspt = window.hbspt = window.hbspt || {};
# 					hbspt.forms = hbspt.forms || {};
# 					hbspt._wpFormsQueue = [];
# 					hbspt.enqueueForm = function(formDef) {
# 						if (hbspt.forms && hbspt.forms.create) {
# 							hbspt.forms.create(formDef);
# 						} else {
# 							hbspt._wpFormsQueue.push(formDef);
# 						}
# 					}
# 					if (!window.hbspt.forms.create) {
# 						Object.defineProperty(window.hbspt.forms, 'create', {
# 							configurable: true,
# 							get: function() {
# 								return hbspt._wpCreateForm;
# 							},
# 							set: function(value) {
# 								hbspt._wpCreateForm = value;
# 								while (hbspt._wpFormsQueue.length) {
# 									var formDef = hbspt._wpFormsQueue.shift();
# 									if (!document.currentScript) {
# 										var formScriptId = 'leadin-forms-v2-js';
# 										hubspot.utils.currentScript = document.getElementById(formScriptId);
# 									}
# 									hbspt._wpCreateForm.call(hbspt.forms, formDef);
# 								}
# 							},
# 						});
# 					}
# 				})();
# 			</script>
# 		<script type="text/javascript">
#            var ajax_url_products_rating_plugin = "https://informationsecuritybuzz.com/wp-admin/admin-ajax.php";
#            var base_url_of_the_site = "https://informationsecuritybuzz.com";
#          window.PAGE_TYPE = "" ;
#          </script><style type="text/css" id="tve_global_variables">:root{}</style>		<script>
# 			document.documentElement.className = document.documentElement.className.replace( 'no-js', 'js' );
# 		</script>
# 				<style>
# 			.no-js img.lazyload { display: none; }
# 			figure.wp-block-image img.lazyloading { min-width: 150px; }
# 							.lazyload, .lazyloading { opacity: 0; }
# 				.lazyloaded {
# 					opacity: 1;
# 					transition: opacity 400ms;
# 					transition-delay: 0ms;
# 				}
# 					</style>
# 		<style id="penci-custom-style" type="text/css">.penci-hide-tagupdated{ display: none !important; } body, .widget ul li a{ font-size: 18px; } .widget ul li, .post-entry, p, .post-entry p { font-size: 18px; line-height: 1.8; } h1, h2, h3, h4, h5, h6, .penci-lgpop-title, #sidebar-nav .menu li a, #navigation .menu li a, a.penci-topbar-post-title, .penci-slider .pencislider-container .pencislider-content .pencislider-title, .penci-slider .pencislider-container .pencislider-content .pencislider-button, .headline-title, .author-quote span, .penci-more-link a.more-link, .author-content h5, .post-pagination h5, .post-box-title, .penci-countdown .countdown-amount, .penci-countdown .countdown-period, .penci-pagination a, .penci-pagination .disable-url, ul.footer-socials li a span, .penci-sidebar-content .widget-title, #respond h3.comment-reply-title span, .widget-social.show-text a span, .footer-widget-wrapper .widget .widget-title, .error-404 .go-back-home a, .home-featured-cat-content .magcat-detail h3 a, .post-entry blockquote cite, .pencislider-container .pencislider-content .pencislider-title, .pencislider-container .pencislider-content .pencislider-button, .post-entry blockquote .author, .tags-share-box.hide-tags.page-share .share-title, .widget ul.side-newsfeed li .side-item .side-item-text h4 a, .thecomment .comment-text span.author, .thecomment .comment-text span.author a, #respond h3, #respond label, .wpcf7 label, div.wpforms-container .wpforms-form.wpforms-form .wpforms-field-label,div.wpforms-container .wpforms-form.wpforms-form input[type=submit], div.wpforms-container .wpforms-form.wpforms-form button[type=submit], div.wpforms-container .wpforms-form.wpforms-form .wpforms-page-button, #respond #submit, .wpcf7 input[type="submit"], .widget_wysija input[type="submit"], .archive-box span, .penci-login-register input[type="submit"], .archive-box h1, .gallery .gallery-caption, .widget input[type="submit"],.penci-button, #main .bbp-login-form .bbp-submit-wrapper button[type="submit"], .widget button[type="submit"], .contact-form input[type=submit], ul.penci-topbar-menu > li a, div.penci-topbar-menu > ul > li a, .penci-recipe-index-wrap .penci-index-more-link a, #bbpress-forums #bbp-search-form .button, .penci-menu-hbg .menu li a, #sidebar-nav .menu li a, .penci-readmore-btn.penci-btn-make-button a, .penci-featured-cat-seemore.penci-btn-make-button a, .penci-menu-hbg-inner .penci-hbg_sitetitle { font-weight: normal; } .featured-area .penci-image-holder, .featured-area .penci-slider4-overlay, .featured-area .penci-slide-overlay .overlay-link, .featured-style-29 .featured-slider-overlay, .penci-slider38-overlay{ border-radius: ; -webkit-border-radius: ; } .penci-featured-content-right:before{ border-top-right-radius: ; border-bottom-right-radius: ; } .penci-flat-overlay .penci-slide-overlay .penci-mag-featured-content:before{ border-bottom-left-radius: ; border-bottom-right-radius: ; } .container-single .post-image{ border-radius: ; -webkit-border-radius: ; } .penci-mega-thumbnail .penci-image-holder{ border-radius: ; -webkit-border-radius: ; } body.penci-body-boxed { background-color:#f5f5f5; } body.penci-body-boxed { background-size:auto; } #logo a { max-width:350px; width: 100%; } @media only screen and (max-width: 960px) and (min-width: 768px){ #logo img{ max-width: 100%; } } .penci-page-container-smaller { max-width:2200px; } .penci-menuhbg-toggle:hover .lines-button:after, .penci-menuhbg-toggle:hover .penci-lines:before, .penci-menuhbg-toggle:hover .penci-lines:after,.tags-share-box.tags-share-box-s2 .post-share-plike,.penci-video_playlist .penci-playlist-title,.pencisc-column-2.penci-video_playlist .penci-video-nav .playlist-panel-item, .pencisc-column-1.penci-video_playlist .penci-video-nav .playlist-panel-item,.penci-video_playlist .penci-custom-scroll::-webkit-scrollbar-thumb, .pencisc-button, .post-entry .pencisc-button, .penci-dropcap-box, .penci-dropcap-circle, .penci-login-register input[type="submit"]:hover, .penci- ...
# var penciBlocksArray=[];
# var portfolioDataJs = portfolioDataJs || [];var PENCILOCALCACHE = {};
# 		(function () {
# 				"use strict";
#
# 				PENCILOCALCACHE = {
# 					data: {},
# 					remove: function ( ajaxFilterItem ) {
# 						delete PENCILOCALCACHE.data[ajaxFilterItem];
# 					},
# 					exist: function ( ajaxFilterItem ) {
# 						return PENCILOCALCACHE.data.hasOwnProperty( ajaxFilterItem ) && PENCILOCALCACHE.data[ajaxFilterItem] !== null;
# 					},
# 					get: function ( ajaxFilterItem ) {
# 						return PENCILOCALCACHE.data[ajaxFilterItem];
# 					},
# 					set: function ( ajaxFilterItem, cachedData ) {
# 						PENCILOCALCACHE.remove( ajaxFilterItem );
# 						PENCILOCALCACHE.data[ajaxFilterItem] = cachedData;
# 					}
# 				};
# 			}
# 		)();function penciBlock() {
# 		    this.atts_json = '';
# 		    this.content = '';
# 		}</script>
# <script type="application/ld+json">{
#     "@context": "https:\/\/schema.org\/",
#     "@type": "organization",
#     "@id": "#organization",
#     "logo": {
#         "@type": "ImageObject",
#         "url": "https:\/\/informationsecuritybuzz.com\/wp-content\/uploads\/isbuzz-news-logo-HR-black-bk-small.png"
#     },
#     "url": "https:\/\/informationsecuritybuzz.com\/",
#     "name": "Information Security Buzz",
#     "description": "Experts Comments on Information Security News"
# }</script><script type="application/ld+json">{
#     "@context": "https:\/\/schema.org\/",
#     "@type": "WebSite",
#     "name": "Information Security Buzz",
#     "alternateName": "Experts Comments on Information Security News",
#     "url": "https:\/\/informationsecuritybuzz.com\/",
#     "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https:\/\/informationsecuritybuzz.com\/search\/{search_term}",
#         "query-input": "required name=search_term"
#     }
# }</script>					<!-- Google Analytics tracking code output by Beehive Analytics Pro -->
# 						<script async src="https://www.googletagmanager.com/gtag/js?id=UA-41913859-1&l=beehiveDataLayer"></script>
# 		<script>
# 						window.beehiveDataLayer = window.beehiveDataLayer || [];
# 			function beehive_ga() {beehiveDataLayer.push(arguments);}
# 			beehive_ga('js', new Date())
# 						beehive_ga('config', 'UA-41913859-1', {
# 				'anonymize_ip': false,
# 				'allow_google_signals': false,
# 			})
# 					</script>
# 		<meta name="generator" content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress."/>
# <script data-ad-client="ca-pub-3711894430425406" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><style type="text/css" id="thrive-default-styles"></style><link rel="icon" href="https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-logo-small-100x100.png" sizes="32x32" />
# <link rel="icon" href="https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-logo-small-250x250.png" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-logo-small-250x250.png" />
# <meta name="msapplication-TileImage" content="https://informationsecuritybuzz.com/wp-content/uploads/isbuzz-logo-small.png" />
# 			<style type="text/css" class="tve_custom_style">@media (min-width: 300px){.tcb-post-list[data-css="tve-u-179cc6a30f7"] .post-wrapper.thrv_wrapper { width: calc((100% - 0px) / 1); padding: 0px; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a30fb"] > .tcb-flex-col { padding-left: 0px; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a30fb"] { margin-left: 0px; min-height: inherit; padding-top: 0px !important; padding-bottom: 0px !important; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a30fa"] { margin-top: 0px !important; margin-bottom: 0px !important; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3104"] { padding-top: 0px !important; margin-top: 0px !important; padding-bottom: 0px !important; padding-left: 20px !important; margin-left: 0px !important; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3105"] { background-image: none !important; border-left: 5px solid rgb(164, 91, 180) !important; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a30fb"] > .tcb-flex-col > .tcb-col { min-height: 282px; }[data-css="tve-u-179cc6a30f7"].tcb-post-list .thrv-content-box [data-css="tve-u-179cc6a3106"] { min-height: 1px; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a30fc"] { box-shadow: none; --tve-applied-box-shadow:none; background-color: transparent !important; padding-left: 30px !important; padding-right: 30px !important; padding-bottom: 30px !important; background-image: linear-gradient(rgb(248, 247, 247), rgb(248, 247, 247)) !important; --background-image:linear-gradient(rgb(248, 247, 247), rgb(248, 247, 247))  !important; --tve-applied-background-image:linear-gradient(rgb(248, 247, 247), rgb(248, 247, 247))  !important; background-size: auto !important; background-position: 50% 50% !important; background-attachment: scroll !important; background-repeat: no-repeat !important; --background-size:auto auto  !important; --background-position:50% 50%  !important; --background-attachment:scroll  !important; --background-repeat:no-repeat  !important; }[data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] { --tve-font-size:16px; --tve-color:rgb(85, 85, 85); --tve-applied---tve-color:rgb(85, 85, 85); padding-left: 20px !important; margin-top: 0px !important; margin-bottom: 0px !important; }:not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] p, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] a, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] ul, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] ul > li, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] ol, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] ol > li, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h1, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h2, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h3, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h4, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h5, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] h6, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] blockquote > p, :not(#tve) [data-css="tve-u-179cc6a30f7"].tcb-post-list [data-css="tve-u-179cc6a3108"] pre { font-size: var(--tve-font-size, 16px); color: var(--tve-color, rgb(85, 85, 85)); --tve-applied-color:var$(--tve-color, rgb(85, 85, 85)); --tcb-applied-color:rgb(85, 85, 85); }[data-css="tve-u-179cc6a30f7"] { padding: 0px; box-shadow: none; --tve-applied-box-shadow:none; background-image: none !important; --ba ...
# 			<noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript></head>
#
# <body class="home page-template-default page page-id-702390 penci-body-boxed soledad-ver-7-9-2 wpb-js-composer js-comp-ver-6.6.0 vc_responsive aa-prefix-infor-">
# <div class="wrapper-boxed header-style-header-5 enable-boxed">
# <div class="penci-header-wrap"><div class="penci-top-bar">
# 	<div class="container">
# 		<div class="penci-headline" role="navigation" itemscope itemtype="https://schema.org/SiteNavigationElement">
# 			<div class="pctopbar-item penci-topbar-trending">
# 			<span class="headline-title nticker-style-1">Top Posts</span>
# 				<span class="penci-trending-nav">
# 			<a class="penci-slider-prev" href="#"><i class="penci-faicon fa fa-angle-left" ></i></a>
# 			<a class="penci-slider-next" href="#"><i class="penci-faicon fa fa-angle-right" ></i></a>
# 		</span>
# 		<div class="penci-owl-carousel penci-owl-carousel-slider penci-headline-posts" data-auto="true" data-nav="false" data-autotime="3000" data-speed="200" data-anim="slideInUp">
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/wave-of-ransomware-draws-government-attention-expert-weighs-in/">Wave Of Ransomware Draws Government Attention, Expert Weighs...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/herfordshire-county-council-reports-almost-16000-cyber-attacks/">Herfordshire County Council Reports Almost 16,000 Cyber &#8216;Attacks&#8217;</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/experts-react-white-house-open-letter-to-companies-re-ransomware/">Experts React: White House Open Letter To Companies...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/bank-fraud-up-159-in-q1-feedzai-reports-expert-offers-perspective/">Bank Fraud Up 159% in Q1, Feedzai Reports...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/security-expert-re-fujifilm-ransomware-attack/">Security Expert Re: FUJIFILM Ransomware Attack</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/expert-react-battle-for-the-galaxy-6-million-gamers-hit-by-data-leak/">Expert React: Battle For The Galaxy &#8211; 6...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/experts-insight-ransomware-attack-on-steamship-authority-of-massachusetts-ferry-service/">Experts Insight: Ransomware Attack On Steamship Authority Of...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/study-research/report-finds-93-percent-of-fraud-attacks-occur-online/">Report Finds 93 Percent of Fraud Attacks Occur...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/world-wide-web-consortium-main-website-goes-down-response-from-outage-expert/">World Wide Web Consortium Main Website Goes Down...</a>
# 				</div>
# 							<div>
# 					<a class="penci-topbar-post-title" href="https://informationsecuritybuzz.com/expert-comments/expert-comment-amazon-and-apple-wide-area-mesh-networking/">Expert Comment: Amazon And Apple Wide-area Mesh Networking</a>
# 				</div>
# 					</div>
# 	</div><div class="pctopbar-item penci-topbar-social">
# 	<div class="inner-header-social">
# 				<a href="https://www.facebook.com/InfoSecBuzz/" aria-label="Facebook"  rel="noreferrer" target="_blank"><i class="penci-faicon fa fa-facebook" ></i></a>
# 						<a href="https://twitter.com/Info_Sec_Buzz" aria-label="Twitter"  rel="noreferrer" target="_blank"><i class="penci-faicon fa fa-twitter" ></i></a>
# 			</div></div>		</div>
# 	</div>
# </div><header id="header" class="header-header-5 has-bottom-line" itemscope="itemscope" itemtype="https://schema.org/WPHeader">
# 			<div class="inner-header penci-header-second">
# 			<div class="container container-fullwidth">
# 				<div id="logo">
# 					<a href="https://informationsecuritybuzz.com/"><img   alt="Information Security Buzz" width="3563" height="1000" data-srcset="https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=234x66&lossy=1&strip=1&webp=1 234w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-300x84.png?lossy=1&strip=1&webp=1 300w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=468x131&lossy=1&strip=1&webp=1 468w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-550x154.png?lossy=1&strip=1&webp=1 550w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-600x168.png?lossy=1&strip=1&webp=1 600w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=702x197&lossy=1&strip=1&webp=1 702w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-768x216.png?lossy=1&strip=1&webp=1 768w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=936x263&lossy=1&strip=1&webp=1 936w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-1200x337.png?lossy=1&strip=1&webp=1 1200w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-1920x539.png?lossy=1&strip=1&webp=1 1920w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=2340x657&lossy=1&strip=1&webp=1 2340w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=3510x985&lossy=1&strip=1&webp=1 3510w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?lossy=1&strip=1&webp=1 3563w"  data-src="https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?lossy=1&strip=1&webp=1" data-sizes="(max-width: 3563px) 100vw, 3563px" class="penci-mainlogo lazyload" src="..." /><noscript><img class="penci-mainlogo" src="https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?lossy=1&strip=1&webp=1" alt="Information Security Buzz" width="3563" height="1000" srcset="https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=234x66&lossy=1&strip=1&webp=1 234w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-300x84.png?lossy=1&strip=1&webp=1 300w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=468x131&lossy=1&strip=1&webp=1 468w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-550x154.png?lossy=1&strip=1&webp=1 550w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-600x168.png?lossy=1&strip=1&webp=1 600w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=702x197&lossy=1&strip=1&webp=1 702w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small-768x216.png?lossy=1&strip=1&webp=1 768w, https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/isbuzz-news-logo-HR-black-bk-small.png?size=936x263&lossy=1&strip=1&webp=1 936w, https://smsh-624100-juc1u ...
#
# 									<div class="header-slogan">
# 						<div class="header-slogan-text">Connecting Security Experts</div>
# 					</div>
#
# 							</div>
# 		</div>
# 								<nav id="navigation" class="header-layout-bottom header-5 menu-style-1" role="navigation" itemscope itemtype="https://schema.org/SiteNavigationElement">
# 			<div class="container container-fullwidth">
# 				<div class="button-menu-mobile header-5"><i class="penci-faicon fa fa-bars" ></i></div>
#
# 				<ul id="menu-second-menu" class="menu"><li id="menu-item-117428" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117428"><a href="https://informationsecuritybuzz.com/?page_id=110496">HOME</a></li>
# <li id="menu-item-444949" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-444949"><a href="https://informationsecuritybuzz.com/domains/">Domains</a>
# <ul class="sub-menu">
# 	<li id="menu-item-117631" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117631"><a href="https://informationsecuritybuzz.com/data-breach/">Data Breach</a></li>
# 	<li id="menu-item-117637" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117637"><a href="https://informationsecuritybuzz.com/malware/">Malware</a></li>
# 	<li id="menu-item-117634" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117634"><a href="https://informationsecuritybuzz.com/application-security/">Application Security</a></li>
# 	<li id="menu-item-117635" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117635"><a href="https://informationsecuritybuzz.com/iot/">IoT</a></li>
# 	<li id="menu-item-117636" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117636"><a href="https://informationsecuritybuzz.com/cloud-security/">Cloud Security</a></li>
# 	<li id="menu-item-117632" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-117632"><a href="https://informationsecuritybuzz.com/privacy/">Privacy</a></li>
# </ul>
# </li>
# <li id="menu-item-444952" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-444952"><a href="https://informationsecuritybuzz.com/deals/">InfoSec Deals</a></li>
# <li id="menu-item-444957" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-444957"><a href="https://informationsecuritybuzz.com/infosec-companies/">Companies</a></li>
# <li id="menu-item-444969" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-444969"><a href="https://informationsecuritybuzz.com/expert-profiles-list/">Security Experts</a></li>
# <li id="menu-item-105591" class="menu-item menu-item-type-post_type menu-item-object-memberpressproduct menu-item-105591"><a href="https://informationsecuritybuzz.com/register/isbuzz-standard/">Register</a></li>
# <li id="menu-item-117753" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-117753"><a href="https://informationsecuritybuzz.com/login/">Log In</a></li>
# </ul>
#
#
# 				<div class="penci-menuhbg-wapper penci-menu-toggle-wapper">
# 	<a href="#pencimenuhbgtoggle" class="penci-menuhbg-toggle">
# 		<span class="penci-menuhbg-inner">
# 			<i class="lines-button lines-button-double">
# 				<i class="penci-lines"></i>
# 			</i>
# 			<i class="lines-button lines-button-double penci-hover-effect">
# 				<i class="penci-lines"></i>
# 			</i>
# 		</span>
# 	</a>
# </div>
# <div id="top-search" class="penci-top-search">
# 	<a class="search-click"><i class="penci-faicon fa fa-search" ></i></a>
# 	<div class="show-search">
# 		<form role="search" method="get" class="pc-searchform" action="https://informationsecuritybuzz.com/">
#     <div>
# 		<input type="text" class="search-input" placeholder="Type and hit enter..." name="s" />
# 	 </div>
# </form>		<a class="search-click close-search"><i class="penci-faicon fa fa-close" ></i></a>
# 	</div>
# </div>			</div>
# 		</nav><!-- End Navigation -->
# 			</header>
# <!-- end #header --></div>
# <div class="container container-single-page container-default-page penci_is_nosidebar">
# 	<div id="main" class="penci-main-single-page-default ">
# 		<div class="theiaStickySidebar">
# 							<article id="post-702390" class="post-702390 page type-page status-publish hentry">
#
# 			<div class="penci-hide-tagupdated">
# 			<span class="author-italic author vcard">Expert(s): <a class="url fn n" href="">muhammad malik</a></span>
# 			<time class="entry-date published" datetime="2021-06-02T13:15:13+00:00">June 2, 2021</time>		</div>
#
#
# 	<div class="post-entry blockquote-style-1 page-has-margin">
# 		<div class="inner-post-entry entry-content">
# 			<div id="tve_flt" class="tve_flt tcb-style-wrap"><div id="tve_editor" class="tve_shortcode_editor tar-main-content" data-post-id="702390"><div class="thrv_wrapper thrv_text_element" style="" data-css="tve-u-179e15b247b"><p>&nbsp; LATEST IN</p></div><div class="thrv_wrapper thrv-columns" style="" data-css="tve-u-179ccc8c18d"><div class="tcb-flex-row v-2 tcb-resized tcb--cols--2" style="" data-css="tve-u-179ccb634ea"><div class="tcb-flex-col" style="" data-css="tve-u-179ccb6ebdf"><div class="tcb-col" style=""><div class="tcb-post-list thrv_wrapper tcb-tablet-hidden" data-type="list" data-pagination-type="none" data-pages_near_current="2" data-css="tve-u-179cca39cad" data-total_post_count="12410" data-total_sticky_count="0" data-disabled-links="0" data-no_posts_text=""><article id="post-702379" class="post-702379 post type-post status-publish format-standard has-post-thumbnail hentry category-expert-comments post-wrapper thrv_wrapper  tve_evt_manager_listen tve_ea_thrive_animation tve_et_mouseover tve_anim_grow" tcb_hover_state_parent="" class="tve_evt_manager_listen tve_ea_thrive_animation tve_et_mouseover tve_anim_grow" data-selector=".post-wrapper" data-permalink="https://informationsecuritybuzz.com/expert-comments/experts-react-on-jbs-foods-hack-must-prompt-supply-chain-cyber-protection/"><style class="tcb-post-list-dynamic-style" type="text/css">@media (min-width: 300px){[data-css="tve-u-179cc6a30f7"].tcb-post-list #post-702379 [data-css="tve-u-179cc6a310a"]{background-image: url("https://smsh-624100-juc1ugur1qwqqqo4.stackpathdns.com/1265760/wp-content/uploads/ID-100124237-300x300.jpg.jpg?lossy=1&strip=1&webp=1") !important;}[data-css="tve-u-179cc6a30f7"].tcb-post-list #post-702379 [data-css="tve-u-179cc6a3109"]:hover [data-css="tve-u-179cc6a310a"]{background-image: linear-gradient(rgba(0, 143, 255, 0.1), rgba(0, 143, 255, 0.1)), url("https://informationsecuritybuzz.com/wp-content/uploads/ID-100124237-300x300.jpg.jpg") !important;}[data-css="tve-u-179cca39cad"].tcb-post-list #post-702379 [data-css="tve-u-179cca39cb0"]{background-image: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url("https://informationsecuritybuzz.com/wp-content/uploads/ID-100124237-300x300.jpg.jpg") !important;}[data-css="tve-u-179cca39cad"].tcb-post-list #post-702379 [data-css="tve-u-179cca39caf"]:hover [data-css="tve-u-179cca39cb0"]{background-image: linear-gradient(rgba(0, 0, 0, 0.4), rgba(0, 0, 0, 0.4)), url("https://informationsecuritybuzz.com/wp-content/uploads/ID-100124237-300x300.jpg.jpg") !important;}[data-css="tve-u-179ccc30e4b"].tcb-post-list #post-702379 [data-css="tve-u-179ccc30e4f"]{background-image: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url("https://informationsecuritybuzz.com/wp-content/uploads/ID-100124237-300x300.jpg.jpg") !important;}[data-css="tve-u-179ccc30e4b"].tcb-post-list #post-702379 [data-css="tve-u-179ccc30e4e"]:hover [data-css="tve-u-179ccc30e4f"]{background-image: linear-gradient(rgba(0, 0, 0, 0.4), rgba(0, 0, 0, 0.4)), url("https://informationsecuritybuzz.com/wp-content/uploads/ID-100124237-300x300.jpg.jpg") !important;}}</style>
# 		<div class="thrv_wrapper thrv_contentbox_shortcode thrv-content-box tve-elem-default-pad tcb-local-vars-root" data-css="tve-u-179cca39caf" style="">
# 	<div class="tve-content-box-background" style="" data-css="tve-u-179cca39cb0" data-tcb_hover_state_parent="1"></div>
# 	<div class="tve-cb"><div class="thrv_wrapper thrv_contentbox_shortcode thrv-content-box tve-elem-default-pad tcb-local-vars-root" data-css="tve-u-179cca39cb1" style="">
# 	<div class="tve-content-box-background" data-css="tve-u-179cca39cb2" data-tcb_hover_state_parent="1"></div>
# 	<div class="tve-cb" data-css="tve-u-179cca39cb3" style=""><div class="thrv_wrapper thrv_text_element tve-froala fr-box fr-basic tcb-local-vars-root" style="" data-css="tve-u-179cca39cb4"><h2 class="" data-css="tve-u-179cca39cb5" style=""><span class="thrive-shortcode-content" data-attr-css="" data-attr-link="1" data-attr-rel="0" data-attr-target="0" data-extra_key="" data-option-inline="1" data-shortcode="tcb_post_title" data-shortcode-name="Post title" style="" data-attr-static-link="{&quot;className&quot;:&quot;tve-froala fr-basic tcb-local-vars-root&quot;,&quot;href&quot;:&quot;https://informationsecuritybuzz.com/expert-comments/herfordshire-county-council-reports-almost-16000-cyber-attacks/&quot;,&quot;title&quot;:&quot;Herfordshire County Council Reports Almost 16,000 Cyber ‘Attacks’&quot;,&quot;class&quot;:&quot;tve-froala fr-basic tcb-local-vars-root&quot;}" data-css="tve-u-179ccb586f1"><a href="https://informationsecuritybuzz.com/expert-comments/experts-react-on-jbs-foods-hack-must-prompt-supply-chain-cyber-protection/" title="Experts React: On JBS Foods Hack Must Prompt Supply Chain Cyber Protection" data-css="" class="tve-froala fr-basic tcb-local-vars-root">Experts React: On JBS Foods Hack Must Prompt Supply Chain Cyber Protection</a></span></h2></div><div class="tcb-post-read-more thrv_wrapper" data-css="tve-u-179cca39cb7" style="">
# 				<a href="https://informationsecuritybuzz.com/expert-comments/experts-react-on-jbs-foods-hack-must-prompt-supply-chain-cyber-protection/" class="tcb-button-link tcb-post-read-more-link" style="">
# 					<span class="tcb-button-texts">
# 						<span class="tcb-button-text thrv-inline-text">Read More</span>
# 					</span>
# 				</a>
# 			</div></div>
# </div></div>
# </div>
#
#
#
#
#
#
#
# ...
# 	<div class="tve-content-box-background" data-css="tve-u-179cc6a3105" style=""></div>
# 	<div class="tve-cb" data-css="tve-u-179cc6a3106"><div class="thrv_wrapper thrv_text_element tve-froala fr-box fr-basic" style=""><h2 class="" style="" data-css="tve-u-179cc6a3107"><span class="thrive-shortcode-content" data-attr-link="1" data-attr-rel="0" data-attr-target="0" data-extra_key="" data-option-inline="1" data-shortcode="tcb_post_title" data-shortcode-name="Post title" data-attr-css="tve-u-179cc782ab2" data-attr-static-link="{&quot;className&quot;:&quot;tve-froala fr-basic&quot;,&quot;href&quot;:&quot;https://informationsecuritybuzz.com/expert-comments/herfordshire-county-council-reports-almost-16000-cyber-attacks/&quot;,&quot;title&quot;:&quot;Herfordshire County Council Reports Almost 16,000 Cyber ‘Attacks’&quot;,&quot;data-css&quot;:&quot;tve-u-179cc782ab2&quot;,&quot;class&quot;:&quot;tve-froala fr-basic&quot;}">{({tcb_post_title link='1' rel='0' target='0' inline='1' css='tve-u-179cc782ab2' static-link='{"className":"tve-froala fr-basic","href":"https://informationsecuritybuzz.com/expert-comments/herfordshire-county-council-reports-almost-16000-cyber-attacks/","title":"Herfordshire County Council Reports Almost 16,000 Cyber ‘Attacks’","data-css":"tve-u-179cc782ab2","class":"tve-froala fr-basic"}' link-css-attr="tve-u-179cc782ab2"})}</span></h2></div></div>
# </div>{({tcb_post_content size='excerpt' read_more='' words='12' css='tve-u-179cc6a3108'})}</div></div><div class="tcb-flex-col" data-css="tve-u-179cc6a5fb3" style=""><div class="tcb-col"><a href="{({tcb_post_the_permalink})}" class="tve-dynamic-link" dynamic-postlink="tcb_post_the_permalink" data-shortcode-id="702386"><div class="thrv_wrapper thrv_contentbox_shortcode thrv-content-box tve-elem-default-pad tcb-local-vars-root" data-css="tve-u-179cc6a3109">
# 	<div class="tve-content-box-background" data-css="tve-u-179cc6a310a" data-tcb_hover_state_parent="1" style=""></div>
# 	<div class="tve-cb" data-css="tve-u-179cc6a310b"></div>
# </div></a></div></div></div></div>
#
#
#
#
#
#
# 	</script><script type="text/javascript">var tcb_post_lists=JSON.parse('[{\"identifier\":\"[data-css=\\\"tve-u-179cca39cad\\\"]\",\"template\":\"tve-u-179cca39cad\",\"attr\":{\"query\":\"{&#039;paged&#039;:1,&#039;filter&#039;:&#039;custom&#039;,&#039;post_type&#039;:[&#039;post&#039;],&#039;related&#039;:[],&#039;orderby&#039;:&#039;modified&#039;,&#039;order&#039;:&#039;DESC&#039;,&#039;posts_per_page&#039;:&#039;1&#039;,&#039;offset&#039;:&#039;1&#039;,&#039;no_posts_text&#039;:&#039;There are no posts to display.&#039;,&#039;exclude_current_post&#039;:[],&#039;queried_object&#039;:{&#039;ID&#039;:702390,&#039;post_author&#039;:&#039;26&#039;,&#039;post_type&#039;:&#039;page&#039;},&#039;sticky&#039;:[],&#039;rules&#039;:[]}\",\"type\":\"list\",\"columns-d\":\"1\",\"columns-t\":\"2\",\"columns-m\":\"1\",\"vertical-space-d\":\"45\",\"horizontal-space-d\":\"45\",\"ct\":\"post_list-43428\",\"ct-name\":\"Image &amp; Text 02\",\"tcb-elem-type\":\"post_list\",\"pagination-type\":\"none\",\"pages_near_current\":\"2\",\"element-name\":\"Post List\",\"css\":\"tve-u-179cca39cad\",\"vertical-space-m\":\"20\",\"total_post_count\":12410,\"total_sticky_count\":0,\"posts_per_page\":1,\"featured-content\":\"0\",\"disabled-links\":\"0\",\"article-tcb_hover_state_parent\":\"\",\"no_posts_text\":\"\",\"class\":\"tcb-tablet-hidden\",\"article-permalink\":\"[tcb-article-permalink]\",\"article-class\":\"tve_evt_manager_listen tve_ea_thrive_animation tve_et_mouseover tve_anim_grow\"},\"query\":{\"paged\":1,\"filter\":\"custom\",\"post_type\":[\"post\"],\"related\":[],\"orderby\":\"modified\",\"order\":\"DESC\",\"posts_per_page\":1,\"offset\":\"1\",\"no_posts_text\":\"There are no posts to display.\",\"exclude_current_post\":[],\"queried_object\":{\"ID\":702390,\"post_author\":\"26\",\"post_type\":\"page\"},\"sticky\":[],\"rules\":[]},\"posts\":[702379]},{\"identifier\":\"[data-css=\\\"tve-u-179ccc30e4b\\\"]\",\"template\":\"tve-u-179ccc30e4b\",\"attr\":{\"query\":\"{&#039;paged&#039;:1,&#039;filter&#039;:&#039;custom&#039;,&#039;post_type&#039;:[&#039;post&#039;],&#039;related&#039;:[],&#039;orderby&#039;:&#039;date&#039;,&#039;order&#039;:&#039;DESC&#039;,&#039;posts_per_page&#039;:&#039;2&#039;,&#039;offset&#039;:&#039;2&#039;,&#039;no_posts_text&#039;:&#039;There are no posts to display.&#039;,&#039;exclude_current_post&#039;:[],&#039;queried_object&#039;:{&#039;ID&#039;:702390,&#039;post_author&#039;:&#039;26&#039;,&#039;post_type&#039;:&#039;page&#039;},&#039;sticky&#039;:[],&#039;rules&#039;:[]}\",\"type\":\"list\",\"columns-d\":\"1\",\"columns-t\":\"2\",\"columns-m\":\"1\",\"vertical-space-d\":\"0\",\"horizontal-space-d\":\"45\",\"ct\":\"post_list-43428\",\"ct-name\":\"Image &amp; Text 02\",\"tcb-elem-type\":\"post_list\",\"pagination-type\":\"none\",\"pages_near_current\":\"2\",\"element-name\":\"Post List\",\"css\":\"tve-u-179ccc30e4b\",\"vertical-space-m\":\"20\",\"total_post_count\":12410,\"total_sticky_count\":0,\"posts_per_page\":2,\"featured-content\":\"0\",\"disabled-links\":\"0\",\"article-tcb_hover_state_parent\":\"\",\"no_posts_text\":\"\",\"class\":\"\",\"article-class\":\"tve_evt_manager_listen tve_ea_thrive_animation tve_et_mouseover tve_anim_grow\"},\"query\":{\"paged\":1,\"filter\":\"custom\",\"post_type\":[\"post\"],\"related\":[],\"orderby\":\"date\",\"order\":\"DESC\",\"posts_per_page\":2,\"offset\":\"2\",\"no_posts_text\":\"There are no posts to display.\",\"exclude_current_post\":[],\"queried_object\":{\"ID\":702390,\"post_author\":\"26\",\"post_type\":\"page\"},\"sticky\":[],\"rules\":[]},\"posts\":[702523,702520]},{\"identifier\":\"[data-css=\\\"tve-u-179e146d499\\\"]\",\"template\":\"tve-u-179e146d499\",\"attr\":{\"query\":\"{&#039;paged&#039;:1,&#039;filter&#039;:&#039;custom&#039;,&#039;post_type&#039;:[&#039;post&#039;],&#039;related&#039;:[],&#039;orderby&#039;:&#039;date&#039;,&#039;order&#039;:&#039;DESC&#039;,&#039;posts_per_page&#039;:&#039;3&#039;,&#039;offset&#039;:&#039;1&#039;,&#039;no_posts_text&#039;:& ...
# 		<script type="text/javascript">
# 		tinyMCEPreInit = {
# 			baseURL: "https://informationsecuritybuzz.com/wp-includes/js/tinymce",
# 			suffix: ".min",
# 			dragDropUpload: true,			mceInit: {'comment_text_area_id':{theme:"modern",skin:"lightgray",language:"en",formats:{alignleft: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"left"}},{selector: "img,table,dl.wp-caption", classes: "alignleft"}],aligncenter: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"center"}},{selector: "img,table,dl.wp-caption", classes: "aligncenter"}],alignright: [{selector: "p,h1,h2,h3,h4,h5,h6,td,th,div,ul,ol,li", styles: {textAlign:"right"}},{selector: "img,table,dl.wp-caption", classes: "alignright"}],strikethrough: {inline: "del"}},relative_urls:false,remove_script_host:false,convert_urls:false,browser_spellcheck:true,fix_list_elements:true,entities:"38,amp,60,lt,62,gt",entity_encoding:"raw",keep_styles:false,cache_suffix:"wp-mce-49110-20201110",resize:"vertical",menubar:false,branding:false,preview_styles:"font-family font-size font-weight font-style text-decoration text-transform",end_container_on_empty_block:true,wpeditimage_html5_captions:true,wp_lang_attr:"en-US",wp_keep_scroll_position:false,wp_shortcut_labels:{"Heading 1":"access1","Heading 2":"access2","Heading 3":"access3","Heading 4":"access4","Heading 5":"access5","Heading 6":"access6","Paragraph":"access7","Blockquote":"accessQ","Underline":"metaU","Strikethrough":"accessD","Bold":"metaB","Italic":"metaI","Code":"accessX","Align center":"accessC","Align right":"accessR","Align left":"accessL","Justify":"accessJ","Cut":"metaX","Copy":"metaC","Paste":"metaV","Select all":"metaA","Undo":"metaZ","Redo":"metaY","Bullet list":"accessU","Numbered list":"accessO","Insert\/edit image":"accessM","Insert\/edit link":"metaK","Remove link":"accessS","Toolbar Toggle":"accessZ","Insert Read More tag":"accessT","Insert Page Break tag":"accessP","Distraction-free writing mode":"accessW","Add Media":"accessM","Keyboard Shortcuts":"accessH"},content_css:"https://informationsecuritybuzz.com/wp-includes/css/dashicons.min.css?ver=5.7.2,https://informationsecuritybuzz.com/wp-includes/js/tinymce/skins/wordpress/wp-content.css?ver=5.7.2,https://informationsecuritybuzz.com/wp-content/plugins/gravityforms/css/shortcode-ui-editor-styles.min.css,https://informationsecuritybuzz.com/wp-content/plugins/gravityforms/css/formsmain.min.css",plugins:"charmap,colorpicker,hr,lists,media,paste,tabfocus,textcolor,fullscreen,wordpress,wpautoresize,wpeditimage,wpemoji,wpgallery,wplink,wpdialogs,wptextpattern,wpview,image",selector:"#comment_text_area_id",wpautop:false,indent:true,toolbar1:"bold,italic,underline,numlist,bullist,link,unlink,media",toolbar2:"",toolbar3:"",toolbar4:"",tabfocus_elements:":prev,:next",body_class:"comment_text_area_id post-type-post post-status-publish post-format-standard page-template-default locale-en-us"}},
# 			qtInit: {'comment_text_area_id':{id:"comment_text_area_id",buttons:"em,strong,link"}},
# 			ref: {plugins:"charmap,colorpicker,hr,lists,media,paste,tabfocus,textcolor,fullscreen,wordpress,wpautoresize,wpeditimage,wpemoji,wpgallery,wplink,wpdialogs,wptextpattern,wpview,image",theme:"modern",language:"en"},
# 			load_ext: function(url,lang){var sl=tinymce.ScriptLoader;sl.markDone(url+'/langs/'+lang+'.js');sl.markDone(url+'/langs/'+lang+'_dlg.js');}
# 		};
# 		</script>
# 		<script type='text/javascript' src='https://informationsecuritybuzz.com/wp-content/uploads/hummingbird-assets/39739b467a6560671125945d0ff2414a.js' id='wphb-10-js'></script>
# <script type='text/javascript'>
# tinymce.addI18n( 'en', {"Ok":"OK","Bullet list":"Bulleted list","Insert\/Edit code sample":"Insert\/edit code sample","Url":"URL","Spellcheck":"Check Spelling","Row properties":"Table row properties","Cell properties":"Table cell properties","Cols":"Columns","Paste row before":"Paste table row before","Paste row after":"Paste table row after","Cut row":"Cut table row","Copy row":"Copy table row","Merge cells":"Merge table cells","Split cell":"Split table cell","Paste is now in plain text mode. Contents will now be pasted as plain text until you toggle this option off.":"Paste is now in plain text mode. Contents will now be pasted as plain text until you toggle this option off.\n\nIf you\u2019re looking to paste rich content from Microsoft Word, try turning this option off. The editor will clean up text pasted from Word automatically.","Rich Text Area. Press ALT-F9 for menu. Press ALT-F10 for toolbar. Press ALT-0 for help":"Rich Text Area. Press Alt-Shift-H for help.","You have unsaved changes are you sure you want to navigate away?":"The changes you made will be lost if you navigate away from this page.","Your browser doesn't support direct access to the clipboard. Please use the Ctrl+X\/C\/V keyboard shortcuts instead.":"Your browser does not support direct access to the clipboard. Please use keyboard shortcuts or your browser\u2019s edit menu instead.","Edit|button":"Edit"});
# tinymce.ScriptLoader.markDone( 'https://informationsecuritybuzz.com/wp-includes/js/tinymce/langs/en.js' );
# </script>
# 		<script type="text/javascript">
# 		var ajaxurl = "/wp-admin/admin-ajax.php";
# 		( function() {
# 			var init, id, $wrap;
#
# 			if ( typeof tinymce !== 'undefined' ) {
# 				if ( tinymce.Env.ie && tinymce.Env.ie < 11 ) {
# 					tinymce.$( '.wp-editor-wrap ' ).removeClass( 'tmce-active' ).addClass( 'html-active' );
# 					return;
# 				}
#
# 				for ( id in tinyMCEPreInit.mceInit ) {
# 					init = tinyMCEPreInit.mceInit[id];
# 					$wrap = tinymce.$( '#wp-' + id + '-wrap' );
#
# 					if ( ( $wrap.hasClass( 'tmce-active' ) || ! tinyMCEPreInit.qtInit.hasOwnProperty( id ) ) && ! init.wp_skip_init ) {
# 						tinymce.init( init );
#
# 						if ( ! window.wpActiveEditor ) {
# 							window.wpActiveEditor = id;
# 						}
# 					}
# 				}
# 			}
#
# 			if ( typeof quicktags !== 'undefined' ) {
# 				for ( id in tinyMCEPreInit.qtInit ) {
# 					quicktags( tinyMCEPreInit.qtInit[id] );
#
# 					if ( ! window.wpActiveEditor ) {
# 						window.wpActiveEditor = id;
# 					}
# 				}
# 			}
# 		}());
# 		</script>
# 				<div id="wp-link-backdrop" style="display: none"></div>
# 		<div id="wp-link-wrap" class="wp-core-ui" style="display: none" role="dialog" aria-labelledby="link-modal-title">
# 		<form id="wp-link" tabindex="-1">
# 		<input type="hidden" id="_ajax_linking_nonce" name="_ajax_linking_nonce" value="3a30744287" />		<h1 id="link-modal-title">Insert/edit link</h1>
# 		<button type="button" id="wp-link-close"><span class="screen-reader-text">Close</span></button>
# 		<div id="link-selector">
# 			<div id="link-options">
# 				<p class="howto" id="wplink-enter-url">Enter the destination URL</p>
# 				<div>
# 					<label><span>URL</span>
# 					<input id="wp-link-url" type="text" aria-describedby="wplink-enter-url" /></label>
# 				</div>
# 				<div class="wp-link-text-field">
# 					<label><span>Link Text</span>
# 					<input id="wp-link-text" type="text" /></label>
# 				</div>
# 				<div class="link-target">
# 					<label><span></span>
# 					<input type="checkbox" id="wp-link-target" /> Open link in a new tab</label>
# 				</div>
# 			</div>
# 			<p class="howto" id="wplink-link-existing-content">Or link to existing content</p>
# 			<div id="search-panel">
# 				<div class="link-search-wrapper">
# 					<label>
# 						<span class="search-label">Search</span>
# 						<input type="search" id="wp-link-search" class="link-search-field" autocomplete="off" aria-describedby="wplink-link-existing-content" />
# 						<span class="spinner"></span>
# 					</label>
# 				</div>
# 				<div id="search-results" class="query-results" tabindex="0">
# 					<ul></ul>
# 					<div class="river-waiting">
# 						<span class="spinner"></span>
# 					</div>
# 				</div>
# 				<div id="most-recent-results" class="query-results" tabindex="0">
# 					<div class="query-notice" id="query-notice-message">
# 						<em class="query-notice-default">No search term specified. Showing recent items.</em>
# 						<em class="query-notice-hint screen-reader-text">Search or use up and down arrow keys to select an item.</em>
# 					</div>
# 					<ul></ul>
# 					<div class="river-waiting">
# 						<span class="spinner"></span>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="submitbox">
# 			<div id="wp-link-cancel">
# 				<button type="button" class="button">Cancel</button>
# 			</div>
# 			<div id="wp-link-update">
# 				<input type="submit" value="Add Link" class="button button-primary" id="wp-link-submit" name="wp-link-submit">
# 			</div>
# 		</div>
# 		</form>
# 		</div>
# 		<script type="text/javascript">!function(a){"use strict";var b=function(b,c,d){function j(a){if(e.body)return a();setTimeout(function(){j(a)})}function l(){f.addEventListener&&f.removeEventListener("load",l),f.media=d||"all"}var g,e=a.document,f=e.createElement("link");if(c)g=c;else{var h=(e.body||e.getElementsByTagName("head")[0]).childNodes;g=h[h.length-1]}var i=e.styleSheets;f.rel="stylesheet",f.href=b,f.media="only x",j(function(){g.parentNode.insertBefore(f,c?g:g.nextSibling)});var k=function(a){for(var b=f.href,c=i.length;c--;)if(i[c].href===b)return a();setTimeout(function(){k(a)})};return f.addEventListener&&f.addEventListener("load",l),f.onloadcssdefined=k,k(l),f};"undefined"!=typeof exports?exports.loadCSS=b:a.loadCSS=b}("undefined"!=typeof global?global:this); !function(a){if(a.loadCSS){var b=loadCSS.relpreload={};if(b.support=function(){try{return a.document.createElement("link").relList.supports("preload")}catch(a){return!1}},b.poly=function(){for(var b=a.document.getElementsByTagName("link"),c=0;c<b.length;c++){var d=b[c];"preload"===d.rel&&"style"===d.getAttribute("as")&&(a.loadCSS(d.href,d,d.getAttribute("media")),d.rel=null)}},!b.support()){b.poly();var c=a.setInterval(b.poly,300);a.addEventListener&&a.addEventListener("load",function(){b.poly(),a.clearInterval(c)}),a.attachEvent&&a.attachEvent("onload",function(){a.clearInterval(c)})}}}(this);</script>
#
#
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.zdnet.com/blog/security/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a'):
    print('  - target: {}'.format(link.get('href')))
    print('    anchor: {}'.format(link.string))

print('headings:')
for heading in soup.find_all('h1'):
    print('  - {}'.format(heading.string))
# Out:
# title: Zero Day | ZDNet
# links:
#   - target: None
#     anchor: None
#   - target: None
#     anchor:
#             Asia
#
#   - target: None
#     anchor:
#             Australia
#
#   - target: None
#     anchor:
#             Europe
#
#   - target: None
#     anchor:
#             India
#
#   - target: None
#     anchor:
#             United Kingdom
#
#   - target: None
#     anchor:
#             United States
#
#   - target: http://www.zdnet.fr/
#     anchor:
#             ZDNet France
#
#   - target: http://www.zdnet.de/
#     anchor:
#             ZDNet Germany
#
#   - target: http://www.zdnet.co.kr/
#     anchor:
#             ZDNet Korea
#
#   - target: http://japan.zdnet.com/
#     anchor:
#             ZDNet Japan
#
#   - target: https://www.zdnet.com/
#     anchor: None
#   - target: None
#     anchor: Search
#   - target: /topic/cloud/
#     anchor:
#                 Cloud
#
#   - target: /topic/cxo/
#     anchor:
#                 CXO
#
#   - target: /topic/hardware/
#     anchor:
#                 Hardware
#
#   - target: /topic/mobility/
#     anchor:
#                 Mobility
#
#   - target: /topic/microsoft/
#     anchor:
#                 Microsoft
#
#   - target: None
#     anchor: more
#   - target: /topic/storage/
#     anchor:
#                 Storage
#
#   - target: /topic/security/
#     anchor:
#                 Security
#
#   - target: /topic/enterprise-software/
#     anchor:
#                 Enterprise Software
#
#   - target: /topic/data-centers/
#     anchor:
#                 Data Centers
#
#   - target: /topic/wearables-fit-for-business/
#     anchor:
#                 Wearables Fit For Business
#
#   - target: /topic/apple/
#     anchor:
#                 Apple
#
#   - target: /topic/innovation/
#     anchor:
#                 Innovation
#
#   - target: /topic/
#     anchor:
#                 See All Topics
#
#   - target: https://www.techrepublic.com/resource-library/whitepapers/
#     anchor:
#                 White Papers
#
#   - target: //downloads.zdnet.com/
#     anchor:
#                 Downloads
#
#   - target: /reviews/
#     anchor:
#                 Reviews
#
#   - target: /pictures/
#     anchor:
#                 Galleries
#
#   - target: /video/
#     anchor:
#                 Videos
#
#   - target: https://www.techrepublic.com/forums/
#     anchor:
#                 TechRepublic Forums
#
#   - target: /newsletters/
#     anchor: Newsletters
#   - target: /blog/
#     anchor: All Writers
#   - target: None
#     anchor: None
#   - target: https://www.zdnet.com/members/preferences/
#     anchor: Preferences
#   - target: https://www.zdnet.com/members/community/
#     anchor: Community
#   - target: https://www.zdnet.com/members/newsletters/
#     anchor: Newsletters
#   - target: https://www.zdnet.com/user/logout/
#     anchor: Log Out
#   - target: https://www.zdnet.com/
#     anchor: None
#   - target: None
#     anchor: None
#   - target: None
#     anchor: Menu
#   - target: /topic/cloud/
#     anchor:
#                 Cloud
#
#   - target: /topic/cxo/
#     anchor:
#                 CXO
#
#   - target: /topic/hardware/
#     anchor:
#                 Hardware
#
#   - target: /topic/mobility/
#     anchor:
#                 Mobility
#
#   - target: /topic/microsoft/
#     anchor:
#                 Microsoft
#
#   - target: /topic/storage/
#     anchor:
#                 Storage
#
#   - target: /topic/security/
#     anchor:
#                 Security
#
#   - target: /topic/enterprise-software/
#     anchor:
#                 Enterprise Software
#
#   - target: /topic/data-centers/
#     anchor:
#                 Data Centers
#
#   - target: /topic/wearables-fit-for-business/
#     anchor:
#                 Wearables Fit For Business
#
#   - target: /topic/apple/
#     anchor:
#                 Apple
#
#   - target: /topic/innovation/
#     anchor:
#                 Innovation
#
#   - target: /topic/
#     anchor:
#                 See All Topics
#
#   - target: https://www.techrepublic.com/resource-library/whitepapers/
#     anchor:
#                 White Papers
#
#   - target: //downloads.zdnet.com/
#     anchor:
#                 Downloads
#
#   - target: /reviews/
#     anchor:
#                 Reviews
#
#   - target: /pictures/
#     anchor:
#                 Galleries
#
#   - target: /video/
#     anchor:
#                 Videos
#
#   - target: https://www.techrepublic.com/forums/
#     anchor:
#                 TechRepublic Forums
#
#   - target: None
#     anchor: None
#   - target: None
#     anchor: None
#   - target: https://www.zdnet.com/members/preferences/
#     anchor: Preferences
#   - target: https://www.zdnet.com/members/community/
#     anchor: Community
#   - target: https://www.zdnet.com/members/newsletters/
#     anchor: Newsletters
#   - target: https://www.zdnet.com/user/logout/
#     anchor: Log Out
#   - target: None
#     anchor: in
#   - target: None
#     anchor:
#             Asia
#
#   - target: None
#     anchor:
#             Australia
#
#   - target: None
#     anchor:
#             Europe
#
#   - target: None
#     anchor:
#             India
#
#   - target: None
#     anchor:
#             United Kingdom
#
#   - target: None
#     anchor:
#             United States
#
#   - target: http://www.zdnet.fr/
#     anchor:
#             ZDNet France
#
#   - target: http://www.zdnet.de/
#     anchor:
#             ZDNet Germany
#
#   - target: http://www.zdnet.co.kr/
#     anchor:
#             ZDNet Korea
#
#   - target: http://japan.zdnet.com/
#     anchor:
#             ZDNet Japan
#
#   - target: https://www.zdnet.com/
#     anchor: ZDNet
#   - target: /blog/
#     anchor: Blog
#   - target: /blog/security/rss.xml
#     anchor: RSS
#   - target: /article/the-cost-of-ransomware-around-the-globe-to-go-beyond-265-billion-in-the-next-decade/
#     anchor: None
#   - target: /article/the-cost-of-ransomware-around-the-globe-to-go-beyond-265-billion-in-the-next-decade/
#     anchor: The cost of ransomware attacks worldwide will go beyond $265 billion in the next decade
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/necro-python-bot-revamped-with-new-vmware-smb-exploits/
#     anchor: None
#   - target: /article/necro-python-bot-revamped-with-new-vmware-smb-exploits/
#     anchor: Necro Python bot revamped with new VMWare, server exploits
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/chinese-cybercriminals-spent-three-years-creating-a-new-backdoor-to-spy-on-governments/
#     anchor: None
#   - target: /article/chinese-cybercriminals-spent-three-years-creating-a-new-backdoor-to-spy-on-governments/
#     anchor: Chinese cybercriminals spent three years creating a new backdoor to spy on governments
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/a-new-surprise-feature-for-norton-360-antivirus-users-you-can-mine-for-cryptocurrency/
#     anchor: None
#   - target: /article/a-new-surprise-feature-for-norton-360-antivirus-users-you-can-mine-for-cryptocurrency/
#     anchor: A new surprise feature for Norton 360 antivirus users: You can mine for cryptocurrency
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/whatsapp-backtracks-on-app-limitations-if-you-dont-agree-to-privacy-changes/
#     anchor: None
#   - target: /article/whatsapp-backtracks-on-app-limitations-if-you-dont-agree-to-privacy-changes/
#     anchor: WhatsApp backtracks on app limitations if you refuse new privacy terms
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/this-is-how-attackers-bypass-microsoft-antimalware-scan-software-amsi/
#     anchor: None
#   - target: /article/this-is-how-attackers-bypass-microsoft-antimalware-scan-software-amsi/
#     anchor: This is how attackers bypass Microsoft's AMSI anti-malware scanning protection
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/xss-vulnerability-found-in-popular-wysiwyg-website-editor/
#     anchor: None
#   - target: /article/xss-vulnerability-found-in-popular-wysiwyg-website-editor/
#     anchor: XSS vulnerability found in popular WYSIWYG website editor
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/russian-underground-forums-launch-competitions-for-cryptocurrency-hacks/
#     anchor: None
#   - target: /article/russian-underground-forums-launch-competitions-for-cryptocurrency-hacks/
#     anchor: Russian underground forums launch competitions for cryptocurrency, NFT hacks
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/us-schools-land-ibm-grants-to-protect-themselves-against-ransomware/
#     anchor: None
#   - target: /article/us-schools-land-ibm-grants-to-protect-themselves-against-ransomware/
#     anchor: US schools land IBM grants to protect themselves against ransomware
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/asian-cybercrime-takedown-leads-to-intercept-of-83-million-in-financial-theft/
#     anchor: None
#   - target: /article/asian-cybercrime-takedown-leads-to-intercept-of-83-million-in-financial-theft/
#     anchor: Asian cybercrime takedown leads to intercept of $83 million in financial theft
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/sec-charges-us-promoters-of-bitconnect-over-marketing-of-alleged-cryptocurrency-scam/
#     anchor: None
#   - target: /article/sec-charges-us-promoters-of-bitconnect-over-marketing-of-alleged-cryptocurrency-scam/
#     anchor: SEC charges US promoters for marketing alleged BitConnect cryptocurrency Ponzi scheme
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/researchers-find-four-new-malware-tools-created-to-exploit-pulse-secure-vpn-appliances/
#     anchor: None
#   - target: /article/researchers-find-four-new-malware-tools-created-to-exploit-pulse-secure-vpn-appliances/
#     anchor: Researchers find four new malware tools created to exploit Pulse Secure VPN appliances
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/fake-human-rights-organization-un-branding-used-to-target-uyghurs-in-ongoing-cyberattacks/
#     anchor: None
#   - target: /article/fake-human-rights-organization-un-branding-used-to-target-uyghurs-in-ongoing-cyberattacks/
#     anchor: Fake human rights organization, UN branding used to target Uyghurs in ongoing cyberattacks
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/bluetooth-bugs-open-the-door-for-attackers-to-impersonate-devices/
#     anchor: None
#   - target: /article/bluetooth-bugs-open-the-door-for-attackers-to-impersonate-devices/
#     anchor: Bluetooth bugs open the door for attackers to impersonate devices
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: /article/russian-national-jailed-for-running-stolen-data-hijacked-account-seller-platform/
#     anchor: None
#   - target: /article/russian-national-jailed-for-running-stolen-data-hijacked-account-seller-platform/
#     anchor: Russian national jailed for running stolen data, hijacked account seller platform deer.io
#   - target: /meet-the-team/us/charlie-osborne/
#     anchor: Charlie Osborne
#   - target: /topic/security/
#     anchor:  Security
#   - target: https://www.zdnet.com/blog/security/
#     anchor: 1
#   - target: https://www.zdnet.com/blog/security/2/
#     anchor: 2
#   - target: https://www.zdnet.com/blog/security/3/
#     anchor: 3
#   - target: https://www.zdnet.com/blog/security/680/
#     anchor: 680
#   - target: https://www.zdnet.com/blog/security/2/
#     anchor: Next
#   - target: None
#     anchor: None
#   - target: https://redventures.com/CMG-terms-of-use.html
#     anchor: Terms of Use
#   - target: https://redventures.com/privacy-policy.html
#     anchor: Privacy Policy
#   - target: https://redventures.com/CMG-terms-of-use.html
#     anchor: Terms of Use
#   - target: https://redventures.com/privacy-policy.html
#     anchor: Privacy Policy
#   - target: /newsletters/
#     anchor: None
#   - target: /members/newsletters/
#     anchor: None
#   - target: /article/colonial-pipeline-ransomware-attack-everything-you-need-to-know/
#     anchor: None
#   - target: /article/colonial-pipeline-ransomware-attack-everything-you-need-to-know/
#     anchor: Colonial Pipeline attack: Everything you need to know
#   - target: /article/remote-code-execution-vulnerabilities-uncovered-in-smart-air-fryer/
#     anchor: None
#   - target: /article/remote-code-execution-vulnerabilities-uncovered-in-smart-air-fryer/
#     anchor: Remote code execution vulnerabilities uncovered in smart air fryer
#   - target: /article/darkside-the-ransomware-group-responsible-for-colonial-pipeline-cyberattack-explained/
#     anchor: None
#   - target: /article/darkside-the-ransomware-group-responsible-for-colonial-pipeline-cyberattack-explained/
#     anchor: DarkSide explained: The ransomware group responsible for Colonial Pipeline attack
#   - target: /article/prominent-security-expert-dan-kaminsky-passes-away-at-42/
#     anchor: None
#   - target: /article/prominent-security-expert-dan-kaminsky-passes-away-at-42/
#     anchor: Prominent security expert Dan Kaminsky passes away at 42
#   - target: /article/ransomware-hits-hundreds-of-dentist-offices-in-the-us/
#     anchor: None
#   - target: /article/ransomware-hits-hundreds-of-dentist-offices-in-the-us/
#     anchor: Ransomware hits hundreds of dentist offices in the US
#   - target: https://www.zdnet.com/
#     anchor: ZDNet
#   - target: https://www.facebook.com/ZDNet/
#     anchor: None
#   - target: https://twitter.com/zdnet
#     anchor: None
#   - target: https://www.linkedin.com/company/zdnet-com
#     anchor: None
#   - target: https://www.youtube.com/channel/UCr9QWb5RKLfaunjKHJZAdQQ
#     anchor: None
#   - target: https://redventures.com/privacy-policy.html
#     anchor: Privacy Policy
#   - target: None
#     anchor: Cookie Settings
#   - target: /advertise/
#     anchor: Advertise
#   - target: https://redventures.com/CMG-terms-of-use.html
#     anchor: Terms of Use
#   - target: https://www.zdnet.com/topic/
#     anchor: Topics
#   - target: https://www.zdnet.com/pictures/
#     anchor: Galleries
#   - target: https://www.zdnet.com/video/
#     anchor: Videos
#   - target: http://narratives.zdnet.com/
#     anchor: Sponsored Narratives
#   - target: https://privacyportal.onetrust.com/webform/79ba7c84-ebc2-4740-8d11-bf1cc4501e59/ae88e03f-2b16-4276-9980-27124ba4b2c1
#     anchor: Do Not Sell My Information
#   - target: /about/
#     anchor: About ZDNet
#   - target: /meet-the-team/
#     anchor: Meet The Team
#   - target: https://www.zdnet.com/blog/
#     anchor: All Authors
#   - target: /rssfeeds/
#     anchor: RSS Feeds
#   - target: /sitemap/
#     anchor: Site Map
#   - target: /reprints/
#     anchor: Reprint Policy
#   - target: https://www.zdnet.com/members/preferences/
#     anchor: Manage
#   - target: https://www.zdnet.com/user/logout/
#     anchor: Log Out
#   - target: None
#     anchor: Join
#   - target: None
#     anchor: Log In
#   - target: /about/
#     anchor: Membership
#   - target: /newsletters/
#     anchor: Newsletters
#   - target: https://cbsi.secure.force.com/CBSi/knowledgehome?referer=zdnet.com
#     anchor: Site Assistance
#   - target: https://academy.zdnet.com/
#     anchor: ZDNet Academy
#   - target: https://www.techrepublic.com/forums/
#     anchor: TechRepublic Forums
# headings:
#   - Zero Day

# %%
import csv

file_location = "D:\Downloads\input-pages-blog-majestic-com.csv"

with open(file_location, mode='r', encoding='utf-8-sig') as csv_file:
    csv_reader = csv.DictReader(csv_file)
 
    for row in csv_reader:
        print(row['URL'])
# Out:
# https://blog.majestic.com/development/flow-metrics/
# https://blog.majestic.com/
# https://blog.majestic.com/company/understanding-googles-algorithm-how-pagerank-works/
# https://blog.majestic.com/general/using-majestic-citation-flow-trust-flow-check-quality-link-prospects/
# https://blog.majestic.com/how-to-videos/
# https://blog.majestic.com/commentary/inside-trust-flow/
# https://blog.majestic.com/general/3d-printing-in-space/
# https://blog.majestic.com/majestic-seo-partners/
# http://blog.majestic.com/
# https://blog.majestic.com/development/compare-backlinks/
# https://blog.majestic.com/company/win-an-ipad/
# https://blog.majestic.com/company/new-domains-now-available-in-site-explorer-preview/
# https://blog.majestic.com/case-studies/million/
# https://blog.majestic.com/wp-content/uploads/2017/08/1.png
# https://blog.majestic.com/pl/objasnienia/linki-nofollow-czym-sa-i-jakie-maja-znaczenie-w-pozycjonowaniu/
# https://blog.majestic.com/training/how-to-optimise-your-site-for-yandex-part-2/
# https://blog.majestic.com/company/twitter/
# https://blog.majestic.com/wp-content/uploads/2010/10/Video-Icon-crop.png
# http://blog.majestic.com/ambassadors/
# https://blog.majestic.com/wp-content/uploads/2014/04/Screen-Shot-2014-04-15-at-16.52.22.png
# https://blog.majestic.com/pl/general/po-polsku/mamy-nadzieje-ze-aktualizacje-wyszukiwarki-site-explorer-nie-uszly-twojej-uwadze
# https://blog.majestic.com/pl/sieci-spolecznosciowe/wywiad-bartosz-szlachetka-moja-kariera-w-seo/
# http://blog.majestic.com/wp-content/uploads/2013/07/5.jpg
# https://blog.majestic.com/wp-content/uploads/2013/07/5.jpg
# https://blog.majestic.com/wp-content/uploads/2016/03/majestic-bcu.png
# https://blog.majestic.com/wp-content/uploads/2019/02/NLP-top-keywords.gif
# https://blog.majestic.com/wp-content/uploads/2019/02/top3-sel-1024x343.gif
# https://blog.majestic.com/wp-content/uploads/2017/03/Crawling-Smarter-2.jpg
# https://blog.majestic.com/wp-content/uploads/2015/09/shutterstock_255170404.jpg
# https://blog.majestic.com/pl/uncategorized-pl/wskazniki-trust-i-citation-flow/
# https://blog.majestic.com/wp-content/uploads/2017/06/Yandex-01.jpg
# https://blog.majestic.com/wp-content/uploads/2016/01/B677X300-NewApproachToBlogging.jpg
# http://blog.majestic.com/wp-content/uploads/2013/06/Screen-Shot-2013-06-07-at-18.52.38.png
# https://blog.majestic.com/wp-content/uploads/2019/02/NLP-api-google-output-1024x457.gif
# https://blog.majestic.com/pl/general/po-polsku/analiza-domeny-majestic-search-explorer-cz1/
# https://blog.majestic.com/wp-content/uploads/2013/06/Screen-Shot-2013-06-07-at-18.52.38.png
# https://blog.majestic.com/wp-content/uploads/2013/10/DomainExtractionFromURL.xlsx
# https://blog.majestic.com/wp-content/uploads/2017/06/Capture-1-.jpg
# https://blog.majestic.com/general/historic-index-update-8/?utm_source=sel&utm_medium=scap&utm_campaign=web
# https://blog.majestic.com/training/a-guide-to-the-majestic-site-explorer/embed/
# https://blog.majestic.com/general/site-explorer-tutorial-2/?utm_source=sel&utm_medium=scap&utm_campaign=web
# https://blog.majestic.com/general/track-competitors-subdomain-root-domain-home-page/
# https://blog.majestic.com/general/majestic-seo-fo-facebook/?utm_source=sel&utm_medium=scap&utm_campaign=web
# https://blog.majestic.com/wp-content/uploads/2013/10/randomurlgenerator.xlsx
# https://blog.majestic.com/pl/sieci-spolecznosciowe/5-mitow-seo-pawel-gontarek/
# https://blog.majestic.com/wp-content/uploads/2013/06/jimloans-domaintools.png
# https://blog.majestic.com/wp-content/uploads/2013/10/Comparison_Template.xlsx
# https://blog.majestic.com/wp-content/uploads/2016/03/MajesticInSpace-MediaRelease.pdf
# https://blog.majestic.com/wp-content/uploads/2019/10/109.Link_Context_Manual_it.pdf

# %%
import csv
from urllib.parse import urlparse, urljoin

file_location = 'D:\Downloads\input-pages-blog-majestic-com.csv'

# Open the CSV file in read mode
with open(file_location, mode='r', encoding='utf-8-sig') as csv_file:
    csv_reader = csv.DictReader(csv_file)

    # A set of resources to fetch later
    prospects = set()

    for row in csv_reader:
        url = urlparse(row['URL'])

        if not url.path.endswith(('/feed/', '.png', '.jpg', '.gif')):
            prospects.add(urljoin(row["URL"], url.path))

print('There are {} prospective pages'.format(len(prospects)))
# Out:
# There are 32 prospective pages

# %%
import csv
import time
from urllib.parse import urlparse, urljoin
import requests

file_location = 'D:\Downloads\input-pages-blog-majestic-com.csv'
output_dir = r"C:\Users\alpra\Documents\blog-down"
index_csv_location = '{}/index-file.csv'.format(output_dir)

# Open the CSV file in read mode
with open(file_location, encoding='utf-8-sig') as csv_file:
    csv_reader = csv.DictReader(csv_file)

    # A set of resources to fetch later
    prospects = set()
    for row in csv_reader:
        url = urlparse(row['URL'])

        if not url.path.endswith(('/feed/', '.png', '.jpg', '.gif')):
            prospects.add(urljoin(row["URL"], url.path))

    print('There are {} prospective pages'.format(len(prospects)))

# Open index file to write output
with open(index_csv_location, mode='w', newline='', encoding='utf-8-sig') as index_csv:
    fieldnames = ['id', 'url', 'filename', 'status', 'location']
    writer = csv.DictWriter(index_csv, fieldnames=fieldnames)
    writer.writeheader()

    page_id = 0

    for url in prospects:
        print('Processing {}'.format(url))

        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            location = ''
            if response.is_redirect:
                location = response.headers.get('Location')
            elif response.status_code == 200:
                response = requests.get(url)

                cache_filename = '{}/page-{}.html'.format(output_dir, page_id)
                with open(cache_filename, mode='w', encoding='utf-8') as cache:
                    cache.write(response.text)

            writer.writerow({
                'id': page_id,
                'url': url,
                'filename': cache_filename,
                'status': response.status_code,
                'location': location
            })
        else:
            print('Ignoring non-HTML content type "{}"'.format(content_type))

        # Pause the execution of the script to prevent an aggressive spam of requests
        time.sleep(1)
# Out:
# There are 32 prospective pages
# Processing https://blog.majestic.com/pl/uncategorized-pl/wskazniki-trust-i-citation-flow/
# Processing https://blog.majestic.com/general/3d-printing-in-space/
# Processing https://blog.majestic.com/development/flow-metrics/
# Processing https://blog.majestic.com/training/a-guide-to-the-majestic-site-explorer/embed/
# Processing https://blog.majestic.com/wp-content/uploads/2019/10/109.Link_Context_Manual_it.pdf
# Ignoring non-HTML content type "application/pdf"
# Processing https://blog.majestic.com/pl/sieci-spolecznosciowe/5-mitow-seo-pawel-gontarek/
# Processing https://blog.majestic.com/general/using-majestic-citation-flow-trust-flow-check-quality-link-prospects/
# Processing https://blog.majestic.com/general/site-explorer-tutorial-2/
# Processing https://blog.majestic.com/pl/general/po-polsku/mamy-nadzieje-ze-aktualizacje-wyszukiwarki-site-explorer-nie-uszly-twojej-uwadze
# Processing https://blog.majestic.com/training/how-to-optimise-your-site-for-yandex-part-2/
# Processing https://blog.majestic.com/general/track-competitors-subdomain-root-domain-home-page/
# Processing https://blog.majestic.com/company/win-an-ipad/
# Processing https://blog.majestic.com/company/understanding-googles-algorithm-how-pagerank-works/
# Processing http://blog.majestic.com/
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/DomainExtractionFromURL.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/company/twitter/
# Processing https://blog.majestic.com/wp-content/uploads/2016/03/MajesticInSpace-MediaRelease.pdf
# Ignoring non-HTML content type "application/pdf"
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/randomurlgenerator.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/
# Processing https://blog.majestic.com/majestic-seo-partners/
# Processing https://blog.majestic.com/pl/sieci-spolecznosciowe/wywiad-bartosz-szlachetka-moja-kariera-w-seo/
# Processing https://blog.majestic.com/development/compare-backlinks/
# Processing https://blog.majestic.com/general/majestic-seo-fo-facebook/
# Processing https://blog.majestic.com/case-studies/million/
# Processing https://blog.majestic.com/how-to-videos/
# Processing https://blog.majestic.com/pl/general/po-polsku/analiza-domeny-majestic-search-explorer-cz1/
# Processing https://blog.majestic.com/commentary/inside-trust-flow/
# Processing https://blog.majestic.com/general/historic-index-update-8/
# Processing https://blog.majestic.com/pl/objasnienia/linki-nofollow-czym-sa-i-jakie-maja-znaczenie-w-pozycjonowaniu/
# Processing https://blog.majestic.com/wp-content/uploads/2013/10/Comparison_Template.xlsx
# Ignoring non-HTML content type "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
# Processing https://blog.majestic.com/company/new-domains-now-available-in-site-explorer-preview/
# Processing http://blog.majestic.com/ambassadors/

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.zdnet.com/blog/security/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('h3'):
        print('  - target: {}'.format(link.get('href')))
        print('    anchor: {}'.format(link.string))

print('headings:')
for heading in soup.find_all('h1'):
    print('  - {}'.format(heading.string))
# Out:
# title: Zero Day | ZDNet
# links:
#   - target: None
#     anchor: Siloscape: this new malware targets Windows containers to access Kubernetes clusters
#   - target: None
#     anchor: The cost of ransomware attacks worldwide will go beyond $265 billion in the next decade
#   - target: None
#     anchor: Necro Python bot revamped with new VMWare, server exploits
#   - target: None
#     anchor: Chinese cybercriminals spent three years creating a new backdoor to spy on governments
#   - target: None
#     anchor: A new surprise feature for Norton 360 antivirus users: You can mine for cryptocurrency
#   - target: None
#     anchor: WhatsApp backtracks on app limitations if you refuse new privacy terms
#   - target: None
#     anchor: This is how attackers bypass Microsoft's AMSI anti-malware scanning protection
#   - target: None
#     anchor: XSS vulnerability found in popular WYSIWYG website editor
#   - target: None
#     anchor: Russian underground forums launch competitions for cryptocurrency, NFT hacks
#   - target: None
#     anchor: US schools land IBM grants to protect themselves against ransomware
#   - target: None
#     anchor: Asian cybercrime takedown leads to intercept of $83 million in financial theft
#   - target: None
#     anchor: SEC charges US promoters for marketing alleged BitConnect cryptocurrency Ponzi scheme
#   - target: None
#     anchor: Researchers find four new malware tools created to exploit Pulse Secure VPN appliances
#   - target: None
#     anchor: Fake human rights organization, UN branding used to target Uyghurs in ongoing cyberattacks
#   - target: None
#     anchor: Bluetooth bugs open the door for attackers to impersonate devices
# headings:
#   - Zero Day

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://informationsecuritybuzz.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a', class_='tve-froala fr-basic'):
        print('  - target: {}'.format(link.get('href')))
        print('    anchor: {}'.format(link.string))

print('headings:')
for heading in soup.find_all('h1'):
    print('  - {}'.format(heading.string))
# Out:
# title: Information Security News | Security Experts Comments On Latest News
# links:
#   - target: https://informationsecuritybuzz.com/articles/technology-blind-spots-is-lack-of-visibility-leaving-your-business-exposed/
#     anchor: Technology Blind Spots: Is Lack Of Visibility Leaving Your Business Exposed?
#   - target: https://informationsecuritybuzz.com/articles/the-central-bank-digital-currency-is-now-a-reality-payment-card-security-needs-to-catch-up/
#     anchor: The Central Bank Digital Currency Is Now A Reality: Payment Card Security Needs To Catch Up
#   - target: https://informationsecuritybuzz.com/articles/the-top-trends-shaping-the-future-of-access-management-in-2021/
#     anchor: The Top Trends Shaping The Future Of Access Management In 2021
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 7, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/leaked-spreadsheet-exposes-details-of-uk-special-forces-soldiers/
#     anchor: Leaked Spreadsheet Exposes Details Of UK Special Forces Soldiers
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 7, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/expert-insight-on-threat-actors-delivering-prevalent-info-stealers-via-pay-per-click-ads/
#     anchor: Expert Insight On Threat Actors Delivering Prevalent Info-stealers Via Pay-per-click Ads
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 7, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/sonicwall-sheds-light-on-ransomware-attacks-as-ncsc-announces-continued-rise/
#     anchor: SonicWall Sheds Light On Ransomware Attacks As NCSC Announces Continued Rise
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 7, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/wave-of-ransomware-draws-government-attention-expert-weighs-in/
#     anchor: Wave Of Ransomware Draws Government Attention, Expert Weighs In
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 4, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/herfordshire-county-council-reports-almost-16000-cyber-attacks/
#     anchor: Herfordshire County Council Reports Almost 16,000 Cyber ‘Attacks’
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 4, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/experts-react-white-house-open-letter-to-companies-re-ransomware/
#     anchor: Experts React: White House Open Letter To Companies Re Ransomware
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 4, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/bank-fraud-up-159-in-q1-feedzai-reports-expert-offers-perspective/
#     anchor: Bank Fraud Up 159% in Q1, Feedzai Reports – Expert Offers Perspective
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 3, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/security-expert-re-fujifilm-ransomware-attack/
#     anchor: Security Expert Re: FUJIFILM Ransomware Attack
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 3, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/expert-react-battle-for-the-galaxy-6-million-gamers-hit-by-data-leak/
#     anchor: Expert React: Battle For The Galaxy – 6 Million Gamers Hit By Data Leak
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 3, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/experts-insight-ransomware-attack-on-steamship-authority-of-massachusetts-ferry-service/
#     anchor: Experts Insight: Ransomware Attack On Steamship Authority Of Massachusetts Ferry Service
#   - target: https://informationsecuritybuzz.com/category/study-research/
#     anchor: Study & Research
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 2, 2021
#   - target: https://informationsecuritybuzz.com/study-research/report-finds-93-percent-of-fraud-attacks-occur-online/
#     anchor: Report Finds 93 Percent of Fraud Attacks Occur Online
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 2, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/world-wide-web-consortium-main-website-goes-down-response-from-outage-expert/
#     anchor: World Wide Web Consortium Main Website Goes Down – Response From Outage Expert
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 2, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/expert-comment-amazon-and-apple-wide-area-mesh-networking/
#     anchor: Expert Comment: Amazon And Apple Wide-area Mesh Networking
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 2, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/doj-charges-woman-with-political-candidate-phishing-attacks/
#     anchor: DOJ Charges Woman With Political Candidate Phishing Attacks
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/06/
#     anchor: June 2, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/experts-react-on-jbs-foods-hack-must-prompt-supply-chain-cyber-protection/
#     anchor: Experts React: On JBS Foods Hack Must Prompt Supply Chain Cyber Protection
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/expert-advice-on-new-crypto-scam-targeting-mobile-users/
#     anchor: Expert Advice on New Crypto Scam Targeting Mobile Users
#   - target: https://informationsecuritybuzz.com/category/articles/
#     anchor: Security Articles
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/articles/technology-blind-spots-is-lack-of-visibility-leaving-your-business-exposed/
#     anchor: Technology Blind Spots: Is Lack Of Visibility Leaving Your Business Exposed?
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/comment-russian-hackers-launch-major-cyberattack-through-u-s-aid-agencys-email-system-microsoft-says/
#     anchor: Russian Hackers Launch Major Cyberattack Through U.S. Aid Agency’s Email System, Microsoft Says
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/implications-of-russian-solarwinds-hackers-new-email-attack-on-government-agencies/
#     anchor: Implications Of Russian Solarwinds Hackers New Email Attack On Government Agencies
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/russia-phishing-attack-on-usaid-other-human-rights-groups/
#     anchor: Russia Phishing Attack On USAID, Other Human Rights Groups
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/expert-advice-on-news-that-fake-movie-streaming-service-leads-to-malware/
#     anchor: Expert Advice on News that Fake Movie Streaming Service Leads to Malware
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 31, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/klarna-privacy-incident-was-self-inflicted-bug/
#     anchor: Klarna Privacy Incident Was ‘Self-Inflicted Bug’, Experts Weigh In
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 27, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/onlyfans-fails-to-prevent-children-from-selling-explicit-videos/
#     anchor: OnlyFans Fails to Prevent Children from Selling Explicit Videos
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 27, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/belgian-government-hacked-by-foreign-power-did-microsoft-let-the-belgians-down/
#     anchor: Belgian Government Hacked By Foreign Power; Did Microsoft Let The Belgians Down?
#   - target: https://informationsecuritybuzz.com/category/expert-comments/
#     anchor: Expert Comments
#   - target: https://informationsecuritybuzz.com/2021/05/
#     anchor: May 27, 2021
#   - target: https://informationsecuritybuzz.com/expert-comments/canada-post-discloses-data-breach/
#     anchor: Canada Post Discloses Data Breach
# headings:
#   - Insert/edit link

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://grahamcluley.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a', ref="bookmark"):
    print('  - target: {}'.format(link.get('href')))
    print('    anchor: {}'.format(link.string))

print('headings:')
for heading in soup.find_all('h1'):
    print('  - {}'.format(heading.string))
# Out:
# title: Graham Cluley • Computer security news, advice, and opinion
# links:
# headings:
#   - Graham Cluley

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a', class_="story-link")__

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
for link in soup.find_all('a', class_="story-link"):  
        print('  - target: {}'.format(link.get('href')))
        
print('headings:')
for heading in soup.find_all('h1'):
    print('  - {}'.format(heading.string))
# Out:
# title: The Hacker News - Cybersecurity News and Analysis
# links:
#   - target: https://thehackernews.com/2021/06/hackers-breached-colonial-pipeline.html
#   - target: https://thehackernews.com/2021/06/latvian-woman-charged-for-her-role-in.html
#   - target: https://thehackernews.com/2021/06/github-updates-policy-to-remove-exploit.html
#   - target: https://thehackernews.com/2021/06/break-into-ethical-hacking-with-18.html
#   - target: https://thehackernews.com/2021/06/tiktok-quietly-updated-its-privacy.html
#   - target: https://thehackernews.com/2021/06/alert-critical-rce-bug-in-vmware.html
#   - target: https://thehackernews.com/2021/06/google-to-let-android-users-opt-out-to.html
#   - target: https://thehackernews.com/2021/06/10-critical-flaws-found-in-codesys.html
# headings:
#   - The Hacker News - Cybersecurity News and Analysis

# %%
import requests
from bs4 import BeautifulSoup
from os import path
import time
import csv
from urllib.parse import urlparse, urljoin
import requests

output_dir = r"C:\Users\alpra\Documents\blog-down"
index_csv_location = '{}/index-file.csv'.format(output_dir)

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
with open(index_csv_location, mode='w', newline='', encoding='utf-8-sig') as index_csv:
    fieldnames = ['id', 'url', 'filename', 'status', 'location']
    writer = csv.DictWriter(index_csv, fieldnames=fieldnames)
    writer.writeheader()
    page_id = 0
    for link in soup.find_all('a', class_="story-link"):
        url = link.get('href')
        html = urlopen(url)
        response = urllib.request.urlopen(url)
        webContent = response.read()
        print('Processing {}'.format(url))
        

        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            location = ''
            if response.is_redirect:
                location = response.headers.get('Location')
            elif response.status_code == 200:
                response = requests.get(url)

                cache_filename = '{}/page-{}.html'.format(output_dir, page_id)
                with open(cache_filename, mode='w', encoding='utf-8') as cache:
                    cache.write(response.text)

            writer.writerow({
                'id': page_id,
                'url': url,
                'filename': cache_filename,
                'status': response.status_code,
                'location': location
            })
        else:
            print('Ignoring non-HTML content type "{}"'.format(content_type))
# Out:
# title: The Hacker News - Cybersecurity News and Analysis
# links:
# Processing https://thehackernews.com/2021/06/hackers-breached-colonial-pipeline.html
# Processing https://thehackernews.com/2021/06/latvian-woman-charged-for-her-role-in.html
# Processing https://thehackernews.com/2021/06/github-updates-policy-to-remove-exploit.html
# Processing https://thehackernews.com/2021/06/break-into-ethical-hacking-with-18.html
# Processing https://thehackernews.com/2021/06/tiktok-quietly-updated-its-privacy.html
# Processing https://thehackernews.com/2021/06/alert-critical-rce-bug-in-vmware.html
# Processing https://thehackernews.com/2021/06/google-to-let-android-users-opt-out-to.html
# Processing https://thehackernews.com/2021/06/10-critical-flaws-found-in-codesys.html

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib
from urllib.parse import urlparse, urljoin
from urllib.request import urlopen



output_dir = r"C:\Users\alpra\Documents\blog-down"

response = requests.get('https://thehackernews.com/')

soup = BeautifulSoup(response.text, 'html.parser')

print('title: {}'.format(soup.title.string))

print('links:')
page_id = 0
for link in soup.find_all('a', class_="story-link"):
    for h2 in soup.find('h2',class_='home-title'):
        url = link.get('href')
        title = link.div.h2.get_text()
        html = urlopen(url)
        response = urllib.request.urlopen(url)
        webContent = response.read()
        print('Processing {}'.format(url))
        print('Title {}'.format(title))
        
 
        # Fetch header first to get check content type
        response = requests.head(url)
        # Content type can contain encoding information after a semi-colon (`;`), which we're not interested in
        content_type = response.headers.get('Content-Type').split(';')[0]

        if content_type == 'text/html':
            page_id += 1
            cache_filename = ''
            response = requests.get(url)
            cache_filename = '{}/{}_page-{}.html'.format(output_dir, title, page_id)
            with open(cache_filename, mode='w', encoding='utf-8') as cache:
                cache.write(response.text)
# Out:
# title: The Hacker News - Cybersecurity News and Analysis
# links:
# Processing https://thehackernews.com/2021/06/shifting-focus-from-reactive-to.html
# Title Shifting the focus from reactive to proactive, with human-led secure coding
# Processing https://thehackernews.com/2021/06/researchers-discover-first-known.html
# Title Researchers Discover First Known Malware Targeting Windows Containers
# Processing https://thehackernews.com/2021/06/hackers-breached-colonial-pipeline.html
# Title Hackers Breached Colonial Pipeline Using Compromised VPN Password
# Processing https://thehackernews.com/2021/06/latvian-woman-charged-for-her-role-in.html
# Title Latvian Woman Charged for Her Role in Creating Trickbot Banking Malware
# Processing https://thehackernews.com/2021/06/github-updates-policy-to-remove-exploit.html
# Title GitHub Updates Policy to Remove Exploit Code When Used in Active Attacks
# Processing https://thehackernews.com/2021/06/break-into-ethical-hacking-with-18.html
# Title Break Into Ethical Hacking With 18 Training Courses For Just $42.99
# Processing https://thehackernews.com/2021/06/tiktok-quietly-updated-its-privacy.html
# Title TikTok Quietly Updated Its Privacy Policy to Collect Users' Biometric Data
# Processing https://thehackernews.com/2021/06/alert-critical-rce-bug-in-vmware.html
# Title ALERT: Critical RCE Bug in VMware vCenter Server Under Active Attack
